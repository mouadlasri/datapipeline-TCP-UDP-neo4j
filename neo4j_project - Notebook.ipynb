# %%
# Author: Mouad Lasri - 67887

# %%
# Installing packages we need through pip in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install pypcapfile
# !{sys.executable} -m pip install py2neo
# !{sys.executable} -m pip install binascii
# !{sys.executable} -m pip install scapy
# Out:
# Requirement already satisfied: pypcapfile in c:\programdata\anaconda3\lib\site-packages (0.12.0)
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# Requirement already satisfied: py2neo in c:\programdata\anaconda3\lib\site-packages (4.3.0)
# Requirement already satisfied: prompt-toolkit~=2.0.7 in c:\programdata\anaconda3\lib\site-packages (from py2neo) (2.0.9)
# Requirement already satisfied: neobolt~=1.7.12 in c:\programdata\anaconda3\lib\site-packages (from py2neo) (1.7.16)
# Requirement already satisfied: urllib3<1.25,>=1.23 in c:\programdata\anaconda3\lib\site-packages (from py2neo) (1.24.1)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from py2neo) (2019.3.9)
# Requirement already satisfied: neotime~=1.7.4 in c:\programdata\anaconda3\lib\site-packages (from py2neo) (1.7.4)
# Requirement already satisfied: click==7.0 in c:\programdata\anaconda3\lib\site-packages (from py2neo) (7.0)
# Requirement already satisfied: pygments~=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from py2neo) (2.3.1)
# Requirement already satisfied: colorama in c:\users\mello\appdata\roaming\python\python37\site-packages (from py2neo) (0.4.1)
# Requirement already satisfied: pytz in c:\programdata\anaconda3\lib\site-packages (from py2neo) (2018.9)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from prompt-toolkit~=2.0.7->py2neo) (0.1.7)
# Requirement already satisfied: six>=1.9.0 in c:\users\mello\appdata\roaming\python\python37\site-packages (from prompt-toolkit~=2.0.7->py2neo) (1.12.0)
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# ERROR: Could not find a version that satisfies the requirement binascii (from versions: none)
# ERROR: No matching distribution found for binascii
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# Requirement already satisfied: scapy in c:\programdata\anaconda3\lib\site-packages (2.4.3)
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# importing the packages we need from "pcapfile"
from pcapfile import savefile
from pcapfile.protocols.linklayer import ethernet
from pcapfile.protocols.network import ip

# %%
# import the module I will need from scapy package
from scapy.all import rdpcap

# %%
# import the modules I will need from py2neo package
from py2neo import Graph, Node, Relationship

# %%
# read pcap file in binary format
pcapfile = open('pcapfile.dump', 'rb')
# load the pcapfile into a variable
capfile = savefile.load_savefile(pcapfile, layers=2, verbose=True)
# Out:
# [+] attempting to load pcapfile.dump
# [+] found valid header
# [+] loaded 1000 packets
# [+] finished loading savefile.

# %%
# To get an overall view of the dump file, we read it with scapy
packets = rdpcap("pcapfile.dump")
print(packets)
# Out:
# <pcapfile.dump: TCP:601 UDP:369 ICMP:30 Other:0>

# %%
# An overall summary
# Not a very detailed summary of data in PCAP file
# It does not tell us if the TCP packet is IPv4 or IPv6
packets.summary()
# Out:
# Ether / IP / TCP 193.235.219.150:http > 132.2.92.145:1813 A
# Ether / IP / TCP 215.46.69.99:ssh > 129.46.85.220:1023 PA
# Ether / IP / ICMP 214.50.42.44 > 208.15.71.88 dest-unreach port-unreachable / IPerror / UDPerror
# Ether / IP / TCP 132.9.99.11:1421 > 210.60.107.64:http A
# Ether / IP / TCP 203.106.142.236:http > 132.9.25.130:2618 A
# Ether / IP / TCP 132.9.25.169:3829 > 193.2.25.132:http A
# Ether / IP / TCP 132.9.99.11:1421 > 210.60.107.64:http PA
# Ether / IP / TCP 132.9.190.38:1113 > 217.178.92.250:http A
# Ether / IP / TCP 211.38.58.124:http > 132.9.33.47:57400 A
# Ether / IP / TCP 171.37.83.48:5103 > 217.178.92.19:http A
# Ether / IP / TCP 173.190.215.205:4533 > 214.161.154.208:smtp A
# Ether / IP / TCP 214.200.3.145:4950 > 221.224.59.49:http A
# Ether / IP / TCP 208.78.69.69:http > 215.46.70.217:34766 A
# Ether / IP / TCP 173.190.215.205:4533 > 214.161.154.208:smtp PA
# Ether / IP / TCP 173.190.199.61:1075 > 209.61.49.65:http S
# Ether / IP / TCP 132.9.25.130:2618 > 203.106.142.236:http A
# Ether / IP / TCP 203.106.142.236:http > 132.9.25.130:2441 A
# Ether / IP / TCP 173.190.215.205:4533 > 214.161.154.208:smtp A
# Ether / IP / TCP 214.200.3.145:1043 > 193.47.22.8:http A
# Ether / IP / TCP 214.200.3.149:4855 > 214.165.185.38:smtp PA
# Ether / IP / TCP 173.190.208.81:2359 > 215.15.152.211:smtp A
# Ether / IP / TCP 214.200.3.149:4774 > 214.170.80.226:smtp PA
# Ether / IP / TCP 214.200.3.166:47309 > 193.18.31.242:http A
# Ether / IP / UDP / DNS Qry
# Ether / IP / TCP 214.200.3.145:1043 > 193.47.22.8:http PA
# Ether / IP / TCP 214.200.3.149:4774 > 214.170.80.226:smtp FA
# Ether / IP / TCP 173.190.22.29:smtp > 130.163.216.202:1419 A
# Ether / IP / TCP 214.200.3.145:4990 > 221.224.59.49:http A
# Ether / IP / TCP 203.106.142.236:http > 132.9.25.130:2569 A
# Ether / IP / TCP 173.190.22.42:smtp > 214.162.23.108:2109 PA
# Ether / IP / TCP 145.18.236.142:2141 > 173.190.216.101:smtp A
# Ether / IP / TCP 192.10.75.214:http > 132.47.219.143:2475 A
# Ether / IP / TCP 154.184.192.152:http > 132.9.33.47:58983 A
# Ether / IP / TCP 210.67.70.84:60572 > 173.190.76.54:smtp PA
# Ether / IP / TCP 203.69.57.253:ftp_data > 173.190.210.146:1252 S
# Ether / IP / TCP 171.37.83.48:5061 > 211.67.197.107:http A
# Ether / IP / TCP 215.46.83.16:64302 > 192.154.14.110:http A
# Ether / IP / TCP 132.9.25.130:2441 > 203.106.142.236:http A
# Ether / IP / TCP 217.178.92.19:http > 132.2.6.52:20418 PA
# Ether / IP / TCP 173.190.232.81:ftp_data > 215.15.157.18:3786 A
# Ether / IP / TCP 129.46.14.188:1717 > 217.178.92.240:http A
# Ether / IP / TCP 132.175.206.208:2148 > 193.144.60.240:http A
# Ether / IP / UDP / DNS Qry
# Ether / IP / TCP 129.46.14.188:1717 > 217.178.92.240:http A
# Ether / IP / TCP 217.178.92.240:http > 132.47.146.91:2011 A
# Ether / IP / TCP 173.190.234.252:pop3 > 214.172.42.65:3330 PA
# Ether / IP / TCP 173.190.214.63:3513 > 221.206.196.238:http A
# Ether / IP / UDP / DNS Qry
# Ether / IP / TCP 214.200.0.96:2051 > 193.235.219.61:http A
# Ether / IP / TCP 214.200.3.145:4937 > 193.235.47.12:http A
# Ether / IP / TCP 217.178.92.241:http > 132.47.196.169:61334 A
# Ether / IP / TCP 214.200.3.145:4937 > 193.235.47.12:http A
# Ether / IP / TCP 210.60.107.64:http > 173.190.214.63:5207 PA
# Ether / IP / TCP 129.46.14.188:1717 > 217.178.92.240:http A
# Ether / IP / TCP 132.9.25.130:2574 > 203.106.142.236:http A
# Ether / IP / TCP 211.190.128.149:http > 173.190.98.214:3792 A
# Ether / IP / TCP 129.46.16.139:1962 > 210.60.113.16:http S
# Ether / IP / TCP 215.46.85.95:5061 > 193.71.46.181:http A
# Ether / IP / TCP 132.9.25.130:2615 > 203.106.142.236:http A
# Ether / IP / TCP 132.9.190.33:1150 > 203.113.220.40:http A
# Ether / IP / TCP 203.106.142.236:http > 132.9.25.130:2420 A
# Ether / IP / TCP 214.200.3.145:4990 > 221.224.59.49:http FA
# Ether / IP / TCP 173.190.216.16:1697 > 210.15.154.38:8888 PA
# Ether / IP / TCP 203.106.142.236:http > 132.9.25.130:2615 FPA
# Ether / IP / TCP 214.200.3.148:2044 > 214.171.62.45:smtp R
# Ether / IP / UDP / DNS Qry
# Ether / IP / TCP 132.9.33.47:57400 > 211.38.58.124:http A
# Ether / IP / TCP 214.200.0.96:2051 > 193.235.219.61:http A
# Ether / IP / TCP 203.106.142.236:http > 132.47.134.53:61003 PA
# Ether / IP / ICMP 209.13.145.149 > 173.190.215.139 echo-reply 0
# Ether / IP / TCP 193.2.172.20:31603 > 173.190.216.96:smtp A
# Ether / IP / TCP 192.23.76.17:10484 > 221.133.178.44:6669 A
# Ether / IP / TCP 132.9.25.130:2615 > 203.106.142.236:http A
# Ether / IP / TCP 211.142.17.78:http > 132.47.209.22:63648 A
# Ether / IP / TCP 217.178.92.24:http > 132.47.196.169:61398 SA
# Ether / IP / ICMP 217.178.92.26 > 132.47.146.91 echo-reply 0
# Ether / IP / TCP 208.42.145.88:1931 > 173.190.211.18:http A
# Ether / IP / TCP 193.235.219.129:http > 132.47.220.4:2588 SA
# Ether / IP / TCP 173.190.234.3:1822 > 217.72.251.124:4604 PA
# Ether / IP / TCP 173.190.215.9:4771 > 193.171.154.61:6667 S
# Ether / IP / TCP 209.13.197.78:http > 173.190.221.45:4000 A
# Ether / IP / TCP 210.60.107.64:http > 173.190.214.63:5207 PA
# Ether / IP / UDP / DNS Qry
# Ether / IP / TCP 173.190.21.86:smtp > 174.60.243.242:2652 A
# Ether / IP / TCP 171.37.201.173:1119 > 193.103.67.174:http FA
# Ether / IP / TCP 193.2.25.132:http > 132.2.142.219:4902 A
# Ether / IP / UDP 208.15.68.115:4000 > 132.47.222.66:64733
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 173.190.215.9:1080 > 215.131.139.173:1108 A
# Ether / IP / TCP 129.46.3.206:1383 > 220.44.134.86:http A
# Ether / IP / TCP 215.46.70.217:34766 > 208.78.69.69:http A
# Ether / IP / TCP 215.46.83.16:64302 > 192.154.14.110:http A
# Ether / IP / TCP 193.145.4.48:http > 132.2.136.225:61123 A
# Ether / IP / TCP 129.46.165.223:1582 > 59.36.81.47:http A
# Ether / IP / TCP 193.2.35.25:47443 > 132.47.192.111:http PA
# Ether / IP / TCP 222.164.196.171:8080 > 132.2.92.24:1966 A
# Ether / IP / UDP / DNS Qry
# Ether / IP / TCP 215.46.83.16:64302 > 192.154.14.110:http A
# Ether / IP / TCP 214.200.3.166:47178 > 209.155.33.16:http A
# Ether / IP / TCP 193.235.219.151:http > 173.190.214.63:5213 PA
# Ether / IP / ICMP 129.46.101.17 > 193.153.53.109 dest-unreach port-unreachable / IPerror / UDPerror
# Ether / IP / TCP 132.9.25.133:2365 > 9.38.174.174:hosts2_ns A
# Ether / IP / TCP 203.106.142.236:http > 132.9.25.130:2531 A
# Ether / IP / TCP 174.51.184.46:http > 132.47.209.22:63665 FA
# Ether / IP / TCP 192.10.75.214:http > 132.47.219.143:2475 PA
# Ether / IP / TCP 132.9.99.77:1128 > 193.144.60.240:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 129.46.177.209:2202 > 221.129.127.32:17309 A
# Ether / IP / TCP 129.46.177.209:2202 > 221.129.127.32:17309 A
# Ether / IP / TCP 132.9.132.170:1857 > 208.1.64.214:http S
# Ether / IP / TCP 193.2.25.132:http > 132.47.192.71:2781 A
# Ether / IP / TCP 132.9.25.169:3838 > 193.2.25.132:http A
# Ether / IP / ICMP 132.9.197.202 > 203.113.53.74 echo-request 0
# Ether / IP / TCP 217.178.92.250:http > 132.9.190.38:1113 A
# Ether / IP / TCP 214.200.3.166:47293 > 192.22.84.12:http A
# Ether / IP / TCP 214.200.3.166:38093 > 192.64.114.66:http A
# Ether / IP / TCP 214.200.3.166:38093 > 192.64.114.66:http A
# Ether / IP / TCP 214.200.3.166:47247 > 214.172.149.149:http FA
# Ether / IP / TCP 132.9.25.130:2569 > 203.106.142.236:http A
# Ether / IP / TCP 132.9.190.33:1160 > 203.113.220.40:http A
# Ether / IP / TCP 132.9.25.169:3838 > 193.2.25.132:http A
# Ether / IP / TCP 173.190.22.42:smtp > 214.172.149.150:14641 A
# Ether / IP / TCP 214.200.3.166:46074 > 192.8.179.254:http A
# Ether / IP / TCP 214.200.3.166:46074 > 192.8.179.254:http A
# Ether / IP / TCP 193.2.25.132:http > 132.47.192.71:2735 A
# Ether / IP / TCP 193.235.92.146:smtp > 173.190.21.86:3077 A
# Ether / IP / TCP 129.46.16.139:1961 > 210.60.113.16:http A
# Ether / IP / TCP 214.200.3.166:47309 > 193.18.31.242:http PA
# Ether / IP / UDP 132.9.33.33:7001 > 154.56.77.118:7003
# Ether / IP / TCP 129.46.177.209:2202 > 221.129.127.32:17309 A
# Ether / IP / TCP 211.3.23.225:http > 173.190.198.112:3416 A
# Ether / IP / TCP 214.200.3.166:47314 > 217.178.92.250:http S
# Ether / IP / TCP 214.200.0.96:2051 > 193.235.219.61:http A
# Ether / IP / TCP 214.200.3.148:2044 > 214.171.62.45:smtp R
# Ether / IP / TCP 129.46.85.220:1023 > 215.46.69.99:ssh A
# Ether / IP / TCP 132.9.190.33:1122 > 203.113.220.40:http R
# Ether / IP / TCP 217.178.92.250:http > 132.2.200.64:3077 A
# Ether / IP / TCP 193.2.35.7:46490 > 173.190.234.149:http A
# Ether / IP / TCP 222.80.230.91:52418 > 173.190.210.196:http A
# Ether / IP / TCP 221.133.178.44:6669 > 192.23.76.17:10484 A
# Ether / IP / UDP 214.50.42.44:50592 > 208.15.68.77:4000
# Ether / IP / TCP 193.144.60.240:http > 173.190.214.63:5200 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 221.133.178.44:6669 > 192.23.76.17:10484 PA
# Ether / IP / TCP 129.46.3.206:1395 > 220.44.134.80:http A
# Ether / IP / TCP 132.9.3.98:1599 > 193.130.154.58:http A
# Ether / IP / TCP 214.200.3.166:47272 > 148.77.81.127:http A
# Ether / IP / ICMP 173.190.208.65 > 211.148.216.250 echo-request 0
# Ether / IP / TCP 214.200.3.166:47336 > 217.130.51.55:http S
# Ether / IP / TCP 217.178.92.242:http > 132.21.63.73:1632 A
# Ether / IP / TCP 214.200.3.166:47335 > 209.222.238.106:http A
# Ether / IP / TCP 217.178.92.24:http > 132.47.196.169:61397 A
# Ether / IP / TCP 129.46.16.139:1961 > 210.60.113.16:http PA
# Ether / IP / TCP 173.190.77.61:64002 > 209.48.201.190:7000 PA
# Ether / IP / TCP 214.200.0.96:2051 > 193.235.219.61:http A
# Ether / IP / TCP 173.190.118.216:4634 > 217.205.144.201:6667 PA
# Ether / IP / TCP 217.178.92.250:http > 132.47.196.169:61352 A
# Ether / IP / TCP 129.46.21.187:1647 > 193.235.219.128:http A
# Ether / IP / TCP 173.190.209.10:2604 > 210.97.250.120:http A
# Ether / IP / TCP 173.190.209.10:2604 > 210.97.250.120:http A
# Ether / IP / UDP / DNS Qry
# Ether / IP / TCP 214.200.3.166:46074 > 192.8.179.254:http A
# Ether / IP / TCP 132.9.99.77:1133 > 193.144.60.240:http A
# Ether / IP / TCP 132.9.190.33:1167 > 203.113.220.40:http A
# Ether / IP / TCP 217.178.92.24:http > 132.47.196.169:61372 A
# Ether / IP / TCP 173.190.208.85:2897 > 134.50.232.246:auth FA
# Ether / IP / TCP 132.9.99.77:1133 > 193.144.60.240:http PA
# Ether / IP / TCP 129.46.3.206:1383 > 220.44.134.86:http A
# Ether / IP / TCP 214.200.0.96:2051 > 193.235.219.61:http A
# Ether / IP / TCP 129.46.16.139:1962 > 210.60.113.16:http A
# Ether / IP / TCP 214.200.3.166:47271 > 217.178.92.67:http A
# Ether / IP / UDP 214.200.9.47:router > 132.25.40.214:router
# Ether / IP / TCP 193.2.29.66:http > 132.47.171.162:62306 A
# Ether / IP / TCP 209.61.52.144:3128 > 173.190.77.32:2873 SA
# Ether / IP / TCP 193.86.162.111:7000 > 173.190.193.1:62865 PA
# Ether / IP / TCP 222.80.230.91:52418 > 173.190.210.196:http A
# Ether / IP / TCP 129.46.3.206:1395 > 220.44.134.80:http A
# Ether / IP / TCP 214.200.3.148:1955 > 193.235.92.146:smtp PA
# Ether / IP / TCP 214.200.0.96:2051 > 193.235.219.61:http FA
# Ether / IP / TCP 214.200.3.148:1955 > 193.235.92.146:smtp FA
# Ether / IP / TCP 193.2.25.132:http > 132.47.134.33:3690 A
# Ether / IP / TCP 171.37.83.48:5103 > 217.178.92.19:http A
# Ether / IP / TCP 173.190.22.42:smtp > 214.172.149.150:14641 PA
# Ether / IP / TCP 129.46.16.139:1962 > 210.60.113.16:http PA
# Ether / IP / TCP 210.209.223.10:http > 173.190.209.10:2874 A
# Ether / IP / UDP / DNS Qry
# Ether / IP / TCP 215.46.83.16:64302 > 192.154.14.110:http A
# Ether / IP / TCP 203.106.142.236:http > 132.9.25.130:2605 PA
# Ether / IP / TCP 214.68.49.213:smtp > 173.190.198.112:3053 FA
# Ether / IP / TCP 193.235.219.144:http > 173.190.214.63:4895 A
# Ether / IP / TCP 173.190.118.216:smtp > 146.162.51.125:30218 PA
# Ether / IP / TCP 129.46.3.206:1382 > 220.44.134.88:http A
# Ether / IP / TCP 132.9.25.130:2531 > 203.106.142.236:http A
# Ether / IP / TCP 132.9.25.130:2420 > 203.106.142.236:http A
# Ether / IP / TCP 9.38.174.174:hosts2_ns > 132.9.25.133:2365 A
# Ether / IP / TCP 129.46.170.232:2727 > 217.130.48.127:http S
# Ether / IP / TCP 222.164.196.203:8080 > 132.2.92.24:1971 PA
# Ether / IP / TCP 173.190.22.29:smtp > 221.215.163.229:1262 PA
# Ether / IP / TCP 173.190.234.9:smtp > 215.196.48.8:45268 A
# Ether / IP / ICMP 173.190.214.95 > 209.13.145.149 echo-request 0
# Ether / IP / TCP 173.190.218.131:3322 > 129.128.94.132:smtp A
# Ether / IP / TCP 173.190.218.131:4785 > 193.235.92.146:smtp PA
# Ether / IP / ICMP 129.46.101.17 > 193.153.53.109 dest-unreach port-unreachable / IPerror / UDPerror
# Ether / IP / TCP 217.178.92.241:http > 132.47.196.169:61334 PA
# Ether / IP / TCP 129.46.14.188:1717 > 217.178.92.240:http A
# Ether / IP / TCP 130.210.135.237:http > 132.47.216.193:3903 A
# Ether / IP / UDP / DNS Qry
# Ether / IP / UDP 214.50.42.44:50535 > 208.15.71.64:4000
# Ether / IP / TCP 193.2.25.132:http > 132.47.192.71:2636 A
# Ether / IP / TCP 214.165.198.240:3312 > 173.190.232.85:ftp R
# Ether / IP / TCP 192.154.170.2:6663 > 173.190.193.1:62946 A
# Ether / IP / TCP 193.2.29.66:http > 132.47.192.71:2766 A
# Ether / IP / TCP 173.190.232.81:ftp_data > 215.15.157.18:3786 A
# Ether / IP / TCP 132.9.190.33:1150 > 203.113.220.40:http A
# Ether / IP / TCP 203.106.142.236:http > 132.9.25.130:2565 A
# Ether / IP / TCP 132.9.190.38:1113 > 217.178.92.250:http A
# Ether / IP / TCP 173.190.232.81:ftp_data > 215.15.157.18:3786 A
# Ether / IP / TCP 173.190.21.86:smtp > 174.60.243.242:2652 A
# Ether / IP / UDP / DNS Qry
# Ether / IP / TCP 203.106.142.236:http > 132.47.134.53:61004 A
# Ether / IP / TCP 129.46.165.223:1578 > 59.36.81.47:http A
# Ether / IP / TCP 21.184.161.43:smtp > 134.50.232.246:4036 A
# Ether / IP / TCP 173.190.215.205:4533 > 214.161.154.208:smtp A
# Ether / IP / TCP 214.200.3.149:4794 > 214.170.80.226:smtp A
# Ether / IP / TCP 214.200.3.148:2022 > 214.179.15.13:smtp FA
# Ether / IP / TCP 132.9.99.11:1421 > 210.60.107.64:http A
# Ether / IP / UDP / DNS Qry
# Ether / IP / TCP 203.106.142.236:http > 132.9.25.130:2618 A
# Ether / IP / TCP 129.46.12.19:3247 > 203.106.142.236:http A
# Ether / IP / TCP 215.46.83.16:64302 > 192.154.14.110:http A
# Ether / IP / TCP 214.50.42.44:50605 > 211.210.13.178:http PA
# Ether / IP / UDP 214.50.42.44:50516 > 208.15.68.67:4000
# Ether / IP / TCP 211.38.58.124:http > 132.9.33.47:57400 A
# Ether / IP / TCP 132.9.25.130:2618 > 203.106.142.236:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 215.46.83.16:64302 > 192.154.14.110:http A
# Ether / IP / TCP 193.235.239.202:http > 221.133.178.46:2198 A
# Ether / IP / TCP 171.37.83.48:5061 > 211.67.197.107:http A
# Ether / IP / TCP 203.106.142.236:http > 132.9.25.130:2519 PA
# Ether / IP / TCP 173.190.199.61:1072 > 209.61.49.100:http A
# Ether / IP / TCP 193.2.25.132:http > 132.2.142.219:4902 A
# Ether / IP / TCP 129.46.86.222:1125 > 203.113.53.77:http R
# Ether / IP / TCP 193.2.35.1:43617 > 132.9.33.37:http FA
# Ether / IP / TCP 192.23.76.82:1551 > 221.133.178.44:6669 A
# Ether / IP / TCP 209.61.49.65:http > 173.190.199.61:1075 SA
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP 129.213.115.194:7001 > 132.9.115.166:7003
# Ether / IP / UDP 214.50.42.44:50532 > 208.15.68.73:4000
# Ether / IP / TCP 193.194.142.138:2474 > 173.190.22.45:smtp S
# Ether / IP / TCP 132.9.33.37:http > 193.2.35.1:43617 A
# Ether / IP / TCP 132.9.25.130:2519 > 203.106.142.236:http A
# Ether / IP / TCP 214.200.3.166:46074 > 192.8.179.254:http A
# Ether / IP / TCP 132.175.206.208:2684 > 193.68.97.38:http A
# Ether / IP / TCP 214.200.3.166:46074 > 192.8.179.254:http A
# Ether / IP / TCP 193.235.219.150:http > 132.21.33.89:1986 A
# Ether / IP / TCP 210.15.154.38:8888 > 173.190.216.16:1697 PA
# Ether / IP / UDP 214.50.42.44:50567 > 208.15.71.73:4000
# Ether / IP / TCP 132.9.99.11:1422 > 210.60.107.64:http S
# Ether / IP / TCP 132.9.190.33:1167 > 203.113.220.40:http PA
# Ether / IP / UDP / DNS Qry
# Ether / IP / TCP 193.2.25.132:http > 132.2.92.145:1818 A
# Ether / IP / TCP 173.190.198.112:3422 > 214.172.42.23:smtp A
# Ether / IP / TCP 214.50.42.44:50526 > 193.225.133.106:http PA
# Ether / IP / TCP 171.37.83.48:5061 > 211.67.197.107:http A
# Ether / IP / TCP 222.164.196.171:8080 > 132.2.92.24:1966 PA
# Ether / IP / TCP 129.46.86.222:1126 > 203.113.53.77:http PA
# Ether / IP / TCP 129.46.86.222:1126 > 203.113.53.77:http R
# Ether / IP / TCP 173.190.210.215:3773 > 210.8.90.23:7000 PA
# Ether / IP / TCP 173.190.77.32:2849 > 209.61.52.144:3128 A
# Ether / IP / TCP 217.178.92.250:http > 132.47.196.169:61375 A
# Ether / IP / TCP 215.175.19.246:ftp_data > 132.47.198.78:1191 A
# Ether / IP / TCP 132.9.99.77:1128 > 193.144.60.240:http A
# Ether / IP / TCP 214.200.3.148:2060 > 214.6.7.45:smtp S
# Ether / IP / TCP 129.46.86.222:1127 > 203.113.53.76:http S
# Ether / IP / TCP 203.106.142.236:http > 132.9.25.130:2459 A
# Ether / IP / TCP 214.200.3.166:47229 > 210.164.192.72:http A
# Ether / IP / TCP 214.200.3.166:47229 > 210.164.192.72:http FA
# Ether / IP / TCP 214.200.3.166:47314 > 217.178.92.250:http A
# Ether / IP / TCP 132.9.33.47:57400 > 211.38.58.124:http A
# Ether / IP / TCP 173.190.193.93:8000 > 222.21.97.188:1663 A
# Ether / IP / TCP 21.184.161.43:smtp > 134.50.232.246:4036 A
# Ether / IP / TCP 193.160.177.19:http > 215.46.83.16:64354 A
# Ether / IP / TCP 214.200.3.148:1961 > 128.30.87.91:smtp PA
# Ether / IP / TCP 214.200.3.166:47314 > 217.178.92.250:http PA
# Ether / IP / TCP 174.60.243.242:2652 > 173.190.21.86:smtp A
# Ether / IP / TCP 132.175.206.208:2684 > 193.68.97.38:http PA
# Ether / IP / TCP 221.133.178.46:2198 > 193.235.239.202:http A
# Ether / IP / TCP 132.9.25.130:2459 > 203.106.142.236:http A
# Ether / IP / TCP 221.133.178.46:2198 > 193.235.239.202:http A
# Ether / IP / TCP 129.46.21.60:1283 > 193.235.219.129:http FA
# Ether / IP / TCP 129.46.90.71:64949 > 203.106.142.236:http A
# Ether / IP / TCP 193.84.221.118:http > 132.9.25.169:3834 A
# Ether / IP / TCP 214.200.3.166:38246 > 193.235.219.146:http A
# Ether / IP / TCP 132.9.190.40:4113 > 217.178.92.250:http PA
# Ether / IP / UDP / DNS Qry
# Ether / IP / TCP 203.106.142.236:http > 132.9.25.130:2604 PA
# Ether / IP / TCP 129.46.177.26:1078 > 148.77.180.160:http A
# Ether / IP / TCP 211.155.62.68:7000 > 173.190.76.133:1026 R
# Ether / IP / TCP 193.2.35.25:47443 > 132.47.192.111:http A
# Ether / IP / ICMP 129.46.101.17 > 171.189.177.235 dest-unreach port-unreachable / IPerror / UDPerror
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 193.130.167.169:29232 > 132.2.136.47:smtp FA
# Ether / IP / TCP 217.72.251.124:4604 > 173.190.234.3:1822 A
# Ether / IP / TCP 217.72.251.124:4604 > 173.190.210.215:3710 PA
# Ether / IP / TCP 129.46.21.60:1444 > 193.235.219.130:http S
# Ether / IP / TCP 214.200.3.166:47335 > 209.222.238.106:http A
# Ether / IP / TCP 214.200.3.166:47336 > 217.130.51.55:http A
# Ether / IP / TCP 130.210.135.237:http > 132.47.216.193:3903 A
# Ether / IP / TCP 132.9.25.169:3834 > 193.84.221.118:http A
# Ether / IP / TCP 132.9.25.130:2604 > 203.106.142.236:http A
# Ether / IP / TCP 129.46.177.26:1077 > 148.77.162.168:http PA
# Ether / IP / UDP 129.46.101.17:28800 > 214.65.158.4:28800
# Ether / IP / TCP 203.106.142.236:http > 132.9.25.130:2420 PA
# Ether / IP / TCP 214.200.3.166:47336 > 217.130.51.55:http PA
# Ether / IP / TCP 214.200.3.148:2026 > 214.179.15.13:smtp A
# Ether / IP / TCP 217.178.92.24:http > 132.47.196.169:61372 PA
# Ether / IP / TCP 214.200.3.166:47272 > 148.77.81.127:http A
# Ether / IP / TCP 171.37.145.32:1043 > 193.2.25.132:http A
# Ether / IP / TCP 132.9.25.133:2365 > 9.38.174.174:hosts2_ns A
# Ether / IP / TCP 133.103.186.172:http > 132.9.229.24:1946 PA
# Ether / IP / TCP 209.13.197.103:http > 132.47.132.107:1144 SA
# Ether / IP / TCP 132.9.99.77:1133 > 193.144.60.240:http A
# Ether / IP / TCP 193.2.25.132:http > 132.47.192.71:2735 A
# Ether / IP / TCP 129.46.16.139:1962 > 210.60.113.16:http A
# Ether / IP / TCP 203.106.142.236:http > 132.2.200.72:2685 PA
# Ether / IP / TCP 214.200.3.166:46074 > 192.8.179.254:http A
# Ether / IP / ICMP 215.77.35.133 > 132.47.134.53 echo-reply 0
# Ether / IP / ICMP 215.77.35.133 > 132.47.134.53 echo-reply 0
# Ether / IP / TCP 203.106.142.236:http > 132.9.25.130:2618 PA
# Ether / IP / TCP 129.46.3.206:1383 > 220.44.134.86:http A
# Ether / IP / TCP 209.155.154.206:http > 132.2.195.112:2396 A
# Ether / IP / TCP 173.190.211.18:http > 208.42.145.88:1933 A
# Ether / IP / TCP 214.200.3.166:47335 > 209.222.238.106:http A
# Ether / IP / TCP 132.9.25.130:2618 > 203.106.142.236:http A
# Ether / IP / TCP 193.235.219.146:http > 132.21.72.123:2480 A
# Ether / IP / TCP 132.9.25.130:2605 > 203.106.142.236:http A
# Ether / IP / TCP 132.9.25.130:2565 > 203.106.142.236:http A
# Ether / IP / TCP 215.46.83.16:64302 > 192.154.14.110:http A
# Ether / IP / TCP 173.190.22.42:27764 > 193.235.92.146:smtp PA
# Ether / IP / UDP / DNS Qry
# Ether / IP / TCP 193.71.46.181:http > 215.46.85.95:5061 A
# Ether / IP / TCP 132.9.99.11:1421 > 210.60.107.64:http A
# Ether / IP / TCP 174.60.243.242:2652 > 173.190.21.86:smtp A
# Ether / IP / UDP / DNS Qry
# Ether / IP / UDP / DNS Qry
# Ether / IP / TCP 209.61.52.144:3128 > 173.190.77.32:2747 FPA
# Ether / IP / TCP 217.178.92.24:http > 132.47.134.78:4287 A
# Ether / IP / TCP 173.190.210.219:2592 > 216.132.241.236:http A
# Ether / IP / TCP 173.190.198.79:smtp > 174.171.18.51:62466 A
# Ether / IP / TCP 173.190.153.114:smtp > 221.215.163.229:3440 PA
# Ether / IP / TCP 173.190.198.79:smtp > 174.171.18.51:62466 PA
# Ether / IP / TCP 193.2.35.1:43617 > 132.9.33.37:http FA
# Ether / IP / TCP 211.109.62.68:http > 132.47.171.165:4368 R
# Ether / IP / TCP 173.190.209.10:2874 > 210.209.223.10:http A
# Ether / IP / TCP 173.190.209.40:smtp > 209.79.87.190:61438 A
# Ether / IP / UDP 208.15.68.87:4000 > 132.47.134.148:2913
# Ether / IP / ICMP 59.81.168.178 > 132.21.49.200 echo-reply 0
# Ether / IP / ICMP 154.56.77.118 > 132.9.33.33 dest-unreach port-unreachable / IPerror / UDPerror
# Ether / IP / TCP 214.162.25.81:smtp > 173.190.76.132:4662 PA
# Ether / IP / TCP 193.171.154.61:6667 > 173.190.215.9:4771 SA
# Ether / IP / TCP 193.235.92.146:smtp > 173.190.218.131:4785 PA
# Ether / IP / TCP 173.190.214.63:5145 > 210.60.107.64:http A
# Ether / IP / TCP 173.190.214.63:5145 > 210.60.107.64:http FA
# Ether / IP / ICMP 173.190.214.60 > 209.13.145.149 echo-request 0
# Ether / IP / TCP 173.190.199.61:1077 > 209.61.49.65:http S
# Ether / IP / TCP 132.9.33.37:http > 193.2.35.1:43617 A
# Ether / IP / TCP 173.190.21.86:smtp > 174.60.243.242:2652 A
# Ether / IP / TCP 193.144.60.240:http > 132.2.92.145:msmq PA
# Ether / IP / TCP 215.46.68.0:31196 > 215.46.68.5:bgp A
# Ether / IP / TCP 209.48.201.190:7000 > 173.190.77.61:64002 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 193.235.92.146:smtp > 173.190.218.131:4785 FA
# Ether / IP / ICMP 209.13.145.149 > 173.190.214.95 echo-reply 0
# Ether / IP / TCP 214.200.3.149:4876 > 214.165.185.38:smtp PA
# Ether / IP / TCP 129.46.170.232:2727 > 217.130.48.127:http A
# Ether / IP / TCP 132.9.99.11:1422 > 210.60.107.64:http A
# Ether / IP / TCP 209.61.49.100:http > 173.190.199.61:1072 A
# Ether / IP / TCP 132.9.99.11:1422 > 210.60.107.64:http PA
# Ether / IP / TCP 129.46.170.232:2727 > 217.130.48.127:http PA
# Ether / IP / TCP 129.46.14.188:1717 > 217.178.92.240:http A
# Ether / IP / TCP 129.46.165.223:1578 > 59.36.81.47:http A
# Ether / IP / TCP 192.10.75.214:http > 132.47.219.143:2474 A
# Ether / IP / TCP 208.42.145.88:1931 > 173.190.211.18:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 211.229.244.41:http > 132.47.192.27:2714 A
# Ether / IP / UDP / DNS Qry
# Ether / IP / TCP 214.200.3.166:47272 > 148.77.81.127:http A
# Ether / IP / TCP 173.190.232.85:http > 214.172.149.28:2539 A
# Ether / IP / TCP 214.200.3.166:46942 > 211.51.72.111:http A
# Ether / IP / TCP 129.46.12.19:3247 > 203.106.142.236:http A
# Ether / IP / TCP 203.106.142.236:http > 132.9.25.130:2531 A
# Ether / IP / TCP 173.190.232.85:http > 214.172.149.28:2539 A
# Ether / IP / TCP 215.46.83.16:64302 > 192.154.14.110:http A
# Ether / IP / TCP 214.193.100.241:1164 > 211.69.166.193:http A
# Ether / IP / TCP 132.9.229.144:1821 > 193.235.219.128:http S
# Ether / IP / UDP / DNS Qry
# Ether / IP / TCP 203.106.142.236:http > 132.9.25.130:2605 A
# Ether / IP / TCP 173.190.232.85:http > 214.172.149.28:2539 A
# Ether / IP / TCP 215.46.83.16:64302 > 192.154.14.110:http A
# Ether / IP / TCP 129.46.86.222:1127 > 203.113.53.76:http A
# Ether / IP / TCP 214.200.3.166:46074 > 192.8.179.254:http A
# Ether / IP / TCP 214.200.3.166:46074 > 192.8.179.254:http A
# Ether / IP / TCP 129.46.86.222:1127 > 203.113.53.76:http A
# Ether / IP / TCP 129.46.3.206:1395 > 220.44.134.80:http A
# Ether / IP / TCP 193.84.221.118:http > 132.9.25.169:3816 A
# Ether / IP / TCP 129.46.86.222:1127 > 203.113.53.76:http PA
# Ether / IP / TCP 215.175.19.246:ftp > 132.47.198.78:1192 PA
# Ether / IP / TCP 173.190.232.85:http > 214.172.149.28:2539 A
# Ether / IP / TCP 129.46.177.209:2202 > 221.129.127.32:17309 A
# Ether / IP / TCP 222.164.196.171:8080 > 132.2.92.24:1968 A
# Ether / IP / TCP 192.10.75.214:http > 132.47.219.143:2475 A
# Ether / IP / TCP 192.23.76.17:10484 > 221.133.178.44:6669 A
# Ether / IP / TCP 173.190.232.85:http > 214.172.149.28:2539 A
# Ether / IP / TCP 132.9.190.33:1147 > 203.113.220.40:http A
# Ether / IP / TCP 9.38.174.174:hosts2_ns > 132.9.25.133:2365 A
# Ether / IP / TCP 215.46.64.251:http > 209.234.88.222:65344 A
# Ether / IP / TCP 221.206.196.238:http > 173.190.214.63:3513 A
# Ether / IP / UDP 208.15.71.76:4000 > 132.47.222.147:64024
# Ether / IP / TCP 173.190.232.85:http > 214.172.149.28:11874 A
# Ether / IP / TCP 132.9.25.130:2420 > 203.106.142.236:http A
# Ether / IP / TCP 132.9.25.169:3829 > 193.2.25.132:http A
# Ether / IP / TCP 193.2.25.132:http > 132.2.92.145:1818 A
# Ether / IP / TCP 173.190.232.85:http > 214.172.149.28:11874 A
# Ether / IP / TCP 173.190.234.33:1237 > 211.130.28.255:6667 A
# Ether / IP / TCP 129.46.21.60:1444 > 193.235.219.130:http A
# Ether / IP / TCP 193.144.76.124:http > 132.47.209.22:63564 A
# Ether / IP / TCP 173.190.232.85:http > 214.172.149.28:11874 A
# Ether / IP / ICMP 129.46.101.17 > 193.81.1.24 dest-unreach port-unreachable / IPerror / UDPerror
# Ether / IP / TCP 203.106.142.236:http > 132.47.220.4:2530 PA
# Ether / IP / TCP 173.190.198.112:3422 > 214.172.42.23:smtp A
# Ether / IP / TCP 129.46.21.60:1444 > 193.235.219.130:http PA
# Ether / IP / TCP 214.200.3.166:47309 > 193.18.31.242:http A
# Ether / IP / TCP 214.200.3.166:45607 > 211.160.205.58:http A
# Ether / IP / TCP 132.9.99.11:1421 > 210.60.107.64:http A
# Ether / IP / TCP 217.178.92.250:http > 132.47.134.78:4746 A
# Ether / IP / TCP 134.50.232.246:auth > 173.190.208.85:2897 A
# Ether / IP / TCP 173.190.198.112:3422 > 214.172.42.23:smtp A
# Ether / IP / TCP 173.190.221.45:4000 > 209.13.197.78:http A
# Ether / IP / TCP 173.190.209.10:2877 > 193.54.210.172:http A
# Ether / IP / TCP 173.190.199.61:1072 > 209.61.49.100:http A
# Ether / IP / TCP 173.190.209.10:2877 > 193.54.210.172:http PA
# Ether / IP / TCP 21.184.161.43:smtp > 134.50.232.246:4036 A
# Ether / IP / UDP / DNS Qry
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 129.46.3.206:1382 > 220.44.134.88:http A
# Ether / IP / TCP 173.190.208.85:smtp > 134.50.232.246:4100 PA
# Ether / IP / TCP 173.190.198.66:62196 > 211.86.80.111:6668 A
# Ether / IP / TCP 173.190.217.86:smtp > 214.172.42.17:1963 A
# Ether / IP / TCP 214.200.3.148:2013 > 214.179.15.13:smtp FA
# Ether / IP / TCP 203.106.142.236:http > 132.9.25.130:2589 PA
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 168.161.18.71:2004 > 209.161.43.224:http PA
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 174.60.243.242:2652 > 173.190.21.86:smtp A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 214.200.3.166:46829 > 209.222.238.106:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 132.9.99.77:1128 > 193.144.60.240:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / ICMP 129.46.97.248 > 193.2.29.66 echo-request 0
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 217.178.92.241:http > 132.47.216.239:4220 A
# Ether / IP / TCP 129.46.165.223:1582 > 59.36.81.47:http A
# Ether / IP / TCP 132.9.25.130:2589 > 203.106.142.236:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 171.37.83.48:5061 > 211.67.197.107:http A
# Ether / IP / TCP 132.9.99.77:1128 > 193.144.60.240:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 132.9.229.24:1946 > 133.103.186.172:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 203.106.142.236:http > 132.47.134.53:61004 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 203.106.142.236:http > 132.9.25.130:2441 PA
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 129.46.14.188:1717 > 217.178.92.240:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 193.2.92.163:http > 132.2.94.242:2038 A
# Ether / IP / TCP 217.205.144.201:6667 > 173.190.118.216:4634 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP 214.50.42.44:50884 > 208.15.68.78:4000
# Ether / IP / TCP 132.9.25.130:2441 > 203.106.142.236:http A
# Ether / IP / TCP 129.46.16.139:1962 > 210.60.113.16:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 217.178.92.242:http > 132.2.89.22:2080 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 21.184.161.43:smtp > 134.50.232.246:4036 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 132.9.99.11:1421 > 210.60.107.64:http PA
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 211.109.62.68:http > 132.47.213.116:1538 A
# Ether / IP / TCP 173.190.215.139:2279 > 59.96.152.25:1080 A
# Ether / IP / TCP 173.190.217.86:smtp > 214.172.42.17:1963 PA
# Ether / IP / TCP 173.190.209.40:smtp > 209.79.87.190:61438 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 214.200.3.166:45607 > 211.160.205.58:http A
# Ether / IP / TCP 214.200.3.166:47336 > 217.130.51.55:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 214.200.3.166:47322 > 214.165.165.72:http S
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Qry
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 203.106.142.236:http > 132.9.25.130:2574 A
# Ether / IP / TCP 132.9.99.77:1133 > 193.144.60.240:http FA
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 132.9.25.130:2605 > 203.106.142.236:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 214.200.3.166:47336 > 217.130.51.55:http FA
# Ether / IP / TCP 132.9.25.130:2531 > 203.106.142.236:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 129.46.170.232:2721 > 203.180.24.31:http A
# Ether / IP / TCP 21.184.161.43:smtp > 134.50.232.246:4036 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 217.178.92.19:http > 132.9.190.40:4096 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 171.37.114.14:smtp > 209.237.22.91:3411 PA
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 214.200.3.166:47334 > 193.235.219.130:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 134.170.92.139:http > 215.46.70.217:34770 A
# Ether / IP / TCP 132.9.190.40:4096 > 217.178.92.19:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / ICMP 211.148.216.250 > 173.190.208.65 echo-reply 0
# Ether / IP / TCP 210.60.120.175:http > 132.2.94.242:knetd A
# Ether / IP / ICMP 217.178.92.26 > 132.47.146.91 echo-reply 0
# Ether / IP / TCP 221.144.180.192:http > 173.190.211.18:3520 SA
# Ether / IP / TCP 221.144.160.239:http > 132.21.72.123:2440 FA
# Ether / IP / TCP 214.200.3.166:47334 > 193.235.219.130:http FA
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 173.190.98.214:3769 > 209.177.184.176:http R
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 215.46.83.16:64302 > 192.154.14.110:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 215.46.70.217:34770 > 134.170.92.139:http A
# Ether / IP / ICMP 129.46.212.0 > 209.12.147.6 echo-request 0
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 211.38.58.124:http > 132.9.33.47:57400 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 173.190.214.63:5224 > 210.60.107.64:http S
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 214.200.3.166:47337 > 162.115.75.93:http S
# Ether / IP / TCP 214.200.20.5:22525 > 221.144.162.61:http S
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 132.9.25.169:3816 > 193.84.221.118:http A
# Ether / IP / TCP 132.9.33.47:57400 > 211.38.58.124:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 211.96.21.239:http > 132.21.131.93:opsmgr A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 132.9.99.77:1136 > 193.144.60.14:8088 S
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 132.9.229.144:1821 > 193.235.219.128:http A
# Ether / IP / TCP 132.9.229.144:1821 > 193.235.219.128:http FA
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 217.178.92.250:http > 132.47.196.169:61375 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 209.61.52.144:3128 > 173.190.77.32:2849 FPA
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 193.2.16.236:http > 132.47.210.91:47972 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 210.97.250.120:http > 173.190.209.10:2604 A
# Ether / IP / TCP 208.15.12.3:1627 > 132.9.33.37:http S
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 173.190.210.215:3817 > 193.2.172.27:smtp A
# Ether / IP / TCP 214.200.3.166:38093 > 192.64.114.66:http A
# Ether / IP / TCP 214.200.3.166:47272 > 148.77.81.127:http A
# Ether / IP / TCP 129.46.18.193:1442 > 211.53.104.153:http A
# Ether / IP / TCP 214.200.3.166:46074 > 192.8.179.254:http A
# Ether / IP / TCP 132.9.33.37:http > 208.15.12.3:1627 SA
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 129.46.101.17:1247 > 211.210.36.42:28840 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 203.106.142.236:http > 132.9.25.130:2459 A
# Ether / IP / TCP 173.190.77.32:2842 > 209.61.52.144:3128 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / ICMP 129.46.101.17 > 193.81.1.24 dest-unreach port-unreachable / IPerror / UDPerror
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 193.160.177.19:http > 215.46.83.16:64354 A
# Ether / IP / UDP / DNS Qry
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 221.206.196.238:http > 173.190.214.63:3513 FPA
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 173.190.77.61:62358 > 217.110.98.251:6667 PA
# Ether / IP / TCP 132.9.25.130:2459 > 203.106.142.236:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 215.175.19.246:ftp_data > 132.47.198.78:1191 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 132.9.25.133:2365 > 9.38.174.174:hosts2_ns A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 129.46.170.232:2727 > 217.130.48.127:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 129.46.170.232:2727 > 217.130.48.127:http FA
# Ether / IP / TCP 217.178.92.250:http > 132.47.134.78:4750 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 215.77.35.133:http > 132.47.134.53:64632 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 129.46.14.188:1717 > 217.178.92.240:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 214.200.3.166:46074 > 192.8.179.254:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 192.10.75.214:http > 132.47.219.143:2475 PA
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 215.46.83.16:64302 > 192.154.14.110:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 132.9.99.11:1422 > 210.60.107.64:http PA
# Ether / IP / TCP 129.46.12.19:3247 > 203.106.142.236:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 132.9.190.33:1167 > 203.113.220.40:http A
# Ether / IP / TCP 193.235.219.146:http > 132.21.72.123:2480 A
# Ether / IP / TCP 193.235.92.146:smtp > 173.190.22.42:27764 A
# Ether / IP / UDP / DNS Qry
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 173.190.210.146:1252 > 203.69.57.253:ftp_data SA
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP 173.190.77.37:3130 > 209.61.52.144:3130
# Ether / IP / UDP 173.190.77.37:3130 > 221.50.98.97:3130
# Ether / IP / TCP 214.200.3.166:38093 > 192.64.114.66:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 214.200.3.166:47309 > 193.18.31.242:http A
# Ether / IP / TCP 192.10.75.214:http > 132.47.219.143:2474 A
# Ether / IP / TCP 210.60.107.64:http > 173.190.214.63:5145 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 203.106.142.236:http > 132.9.25.130:2604 PA
# Ether / IP / TCP 214.200.3.166:47309 > 193.18.31.242:http A
# Ether / IP / TCP 214.200.3.166:47309 > 193.18.31.242:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 215.46.83.16:64302 > 192.154.14.110:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 208.78.69.69:http > 215.46.70.217:34766 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 173.190.211.18:http > 208.42.145.88:1931 A
# Ether / IP / UDP 173.190.77.37:3130 > 221.50.98.97:3130
# Ether / IP / TCP 173.190.235.112:2116 > 214.179.15.45:sunrpc S
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP 173.190.77.37:3130 > 209.61.52.144:3130
# Ether / IP / TCP 173.190.216.96:smtp > 193.2.172.20:31603 PA
# Ether / IP / TCP 173.190.214.63:5207 > 210.60.107.64:http A
# Ether / IP / UDP 173.190.77.37:3130 > 209.61.52.144:3130
# Ether / IP / TCP 214.200.3.148:2013 > 214.179.15.13:smtp R
# Ether / IP / TCP 129.46.90.71:64949 > 203.106.142.236:http A
# Ether / IP / TCP 214.200.3.148:2013 > 214.179.15.13:smtp R
# Ether / IP / TCP 21.184.161.43:smtp > 134.50.232.246:4036 A
# Ether / IP / TCP 171.37.83.48:5061 > 211.67.197.107:http A
# Ether / IP / TCP 168.161.18.71:2004 > 209.161.43.224:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 173.190.216.101:smtp > 145.18.236.142:2141 A
# Ether / IP / TCP 203.106.142.236:http > 132.2.200.72:2685 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 173.190.214.63:5207 > 210.60.107.64:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP 173.190.77.37:3130 > 221.50.98.97:3130
# Ether / IP / TCP 173.190.214.63:5213 > 193.235.219.151:http A
# Ether / IP / TCP 214.200.3.148:2013 > 214.179.15.13:smtp R
# Ether / IP / TCP 214.200.3.148:2050 > 214.165.185.38:smtp PA
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 203.106.142.236:http > 132.2.200.72:2699 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 129.46.21.60:1444 > 193.235.219.130:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 210.97.250.120:http > 173.190.209.10:2604 A
# Ether / IP / TCP 214.200.3.145:4524 > 210.191.55.221:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP 129.46.101.17:28800 > 211.228.113.42:28800
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 132.9.25.169:3858 > 193.2.29.72:http S
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 217.178.92.24:http > 132.47.134.78:4287 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 214.200.3.166:46074 > 192.8.179.254:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 214.200.3.145:1043 > 193.47.22.8:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 203.106.142.236:http > 132.9.25.130:2459 PA
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / ICMP 173.190.118.221 > 214.179.15.13 dest-unreach host-unreachable / IPerror / UDPerror
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 129.46.3.206:1383 > 220.44.134.86:http A
# Ether / IP / ICMP 173.190.118.221 > 214.179.15.13 dest-unreach host-unreachable / IPerror / UDPerror
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 217.178.92.24:http > 132.21.72.189:1726 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 132.9.25.130:2459 > 203.106.142.236:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 215.77.35.133:http > 132.47.134.53:64632 A
# Ether / IP / ICMP 173.190.118.221 > 214.179.15.13 dest-unreach host-unreachable / IPerror / UDPerror
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 217.178.92.24:http > 132.47.196.169:61398 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 129.46.3.206:1383 > 220.44.134.86:http A
# Ether / IP / ICMP 173.190.118.221 > 214.179.15.13 dest-unreach host-unreachable / IPerror / UDPerror
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 129.46.16.139:1961 > 210.60.113.16:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 217.178.92.24:http > 132.47.192.118:1728 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 132.9.190.33:1147 > 203.113.220.40:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 217.178.92.250:http > 132.47.196.169:61375 PA
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 217.178.92.24:http > 132.21.72.189:1728 A
# Ether / IP / UDP / DNS Qry
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 173.190.234.149:http > 193.2.35.7:46490 A
# Ether / IP / TCP 129.46.14.188:1710 > 217.178.92.240:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 214.200.3.148:1966 > 214.162.24.12:smtp PA
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 193.2.16.247:http > 132.2.163.36:1414 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 129.46.170.232:2721 > 203.180.24.31:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 129.46.16.139:1962 > 210.60.113.16:http A
# Ether / IP / TCP 129.46.16.139:1960 > 148.77.185.155:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 217.178.92.250:http > 132.9.190.38:1113 PA
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 173.190.234.149:http > 193.2.35.7:46490 A
# Ether / IP / TCP 173.190.152.28:smtp > 214.172.149.150:28639 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Qry
# Ether / IP / UDP / DNS Qry
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 193.40.214.124:http > 132.9.43.150:1047 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 173.190.234.149:http > 193.2.35.7:46490 A
# Ether / IP / TCP 173.190.198.112:3416 > 211.3.23.225:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 173.190.208.81:2359 > 215.15.152.211:smtp PA
# Ether / IP / TCP 21.184.161.43:smtp > 134.50.232.246:4036 A
# Ether / IP / TCP 173.190.76.54:smtp > 210.67.70.84:60572 PA
# Ether / IP / TCP 132.9.99.11:1421 > 210.60.107.64:http A
# Ether / IP / ICMP 129.46.101.17 > 171.189.177.235 dest-unreach port-unreachable / IPerror / UDPerror
# Ether / IP / TCP 132.9.190.38:1113 > 217.178.92.250:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 193.2.25.132:http > 132.2.136.194:3064 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 132.9.25.130:2574 > 203.106.142.236:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 215.46.85.95:5061 > 193.71.46.181:http A
# Ether / IP / TCP 209.155.154.206:http > 132.2.195.112:2396 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 220.143.5.189:http > 132.47.213.118:2868 SA
# Ether / IP / UDP 131.24.135.67:7001 > 132.9.115.166:7003
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 214.200.20.5:22525 > 221.144.162.61:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 214.200.20.5:22525 > 221.144.162.61:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 129.46.90.71:64936 > 203.106.142.236:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 9.38.174.174:hosts2_ns > 132.9.25.133:2365 A
# Ether / IP / TCP 214.200.20.5:22525 > 221.144.162.61:http PA
# Ether / IP / TCP 215.46.70.217:34766 > 208.78.69.69:http A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 171.37.89.97:http > 193.2.35.25:47156 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans
# Ether / IP / ICMP 215.46.69.102 > 171.37.103.156 time-exceeded ttl-zero-during-transit / IPerror / UDPerror
# Ether / IP / TCP 203.106.142.236:http > 132.9.25.130:2605 A
# Ether / IP / TCP 173.190.208.81:2354 > 209.14.28.189:smtp A
# Ether / IP / TCP 214.200.3.148:2055 > 209.14.28.189:smtp S
# Ether / IP / TCP 203.106.142.236:http > 132.9.25.130:2531 PA
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 214.200.3.166:47272 > 148.77.81.127:http A
# Ether / IP / TCP 214.200.3.166:47314 > 217.178.92.250:http PA
# Ether / IP / TCP 214.200.3.166:46829 > 209.222.238.106:http A
# Ether / IP / TCP 129.46.3.206:1389 > 220.44.134.86:http A
# Ether / IP / TCP 214.200.3.166:46829 > 209.222.238.106:http A
# Ether / IP / TCP 214.200.3.166:46829 > 209.222.238.106:http A
# Ether / IP / TCP 214.200.3.166:46829 > 209.222.238.106:http A
# Ether / IP / ICMP 173.190.215.139 > 209.13.145.149 echo-request 0
# Ether / IP / TCP 132.9.99.77:1126 > 193.144.60.240:http A
# Ether / IP / TCP 214.200.3.148:2022 > 214.179.15.13:smtp R
# Ether / IP / TCP 214.200.3.148:2022 > 214.179.15.13:smtp R
# Ether / IP / TCP 214.200.3.148:2022 > 214.179.15.13:smtp R
# Ether / IP / TCP 215.46.83.16:64302 > 192.154.14.110:http A
# Ether / IP / TCP 214.200.3.166:47165 > 214.165.165.72:http R
# Ether / IP / TCP 203.106.142.236:http > 132.9.25.130:2420 A
# Ether / IP / UDP / DNS Ans
# Ether / IP / TCP 214.200.3.166:47337 > 162.115.75.93:http A
# Ether / IP / TCP 129.46.86.222:1127 > 203.113.53.76:http A
# Ether / IP / TCP 214.200.3.149:4759 > 214.170.80.226:smtp PA
# Ether / IP / TCP 214.200.3.166:47337 > 162.115.75.93:http PA
# Ether / IP / TCP 129.46.16.139:1961 > 210.60.113.16:http FA
# Ether / IP / TCP 193.235.219.128:http > 132.47.135.24:1287 A
# Ether / IP / TCP 129.46.3.206:1395 > 220.44.134.80:http A
# Ether / IP / TCP 214.200.3.166:47309 > 193.18.31.242:http A
# Ether / IP / TCP 214.200.3.166:47309 > 193.18.31.242:http A
# Ether / IP / TCP 132.9.99.77:1136 > 193.144.60.14:8088 A
# Ether / IP / TCP 193.235.219.130:http > 132.21.33.89:2001 A
# Ether / IP / TCP 129.46.3.206:1395 > 220.44.134.80:http A
# Ether / IP / TCP 132.9.99.77:1136 > 193.144.60.14:8088 PA
# Ether / IP / UDP 129.46.101.17:28800 > 215.149.12.107:28800
# Ether / IP / TCP 203.106.142.236:http > 132.2.200.72:2714 A
# Ether / IP / TCP 173.190.198.112:3422 > 214.172.42.23:smtp A
# Ether / IP / TCP 214.200.3.166:47279 > 222.99.14.81:http A
# Ether / IP / TCP 214.200.3.166:47279 > 222.99.14.81:http FA
# Ether / IP / TCP 173.190.198.112:3053 > 214.68.49.213:smtp A
# Ether / IP / TCP 173.190.216.44:1173 > 209.13.197.96:8002 PA
# Ether / IP / TCP 129.46.69.210:1143 > 193.68.97.142:http S
# Ether / IP / TCP 171.37.83.48:5061 > 211.67.197.107:http A
# Ether / IP / TCP 209.61.49.100:http > 173.190.199.61:1072 A
# Ether / IP / ICMP 59.81.168.178 > 132.21.49.200 echo-reply 0
# Ether / IP / TCP 173.190.221.45:4000 > 209.13.197.78:http A
# Ether / IP / ICMP 214.50.42.44 > 209.12.147.6 echo-request 0
# Ether / IP / TCP 214.200.3.166:46829 > 209.222.238.106:http A

# %%
# A more detailed view of the pcap file
# It tells us whether the packet an IPv4 address type of IPv6
for number, packet in enumerate(packets.sessions()):
    print(capfile.packets[number].packet.payload)
# Out:
# ipv4 packet from b'193.235.219.150' to b'132.2.92.145' carrying 20 bytes
# ipv4 packet from b'215.46.69.99' to b'129.46.85.220' carrying 20 bytes
# ipv4 packet from b'214.50.42.44' to b'208.15.71.88' carrying 36 bytes
# ipv4 packet from b'132.9.99.11' to b'210.60.107.64' carrying 20 bytes
# ipv4 packet from b'203.106.142.236' to b'132.9.25.130' carrying 20 bytes
# ipv4 packet from b'132.9.25.169' to b'193.2.25.132' carrying 20 bytes
# ipv4 packet from b'132.9.99.11' to b'210.60.107.64' carrying 20 bytes
# ipv4 packet from b'132.9.190.38' to b'217.178.92.250' carrying 20 bytes
# ipv4 packet from b'211.38.58.124' to b'132.9.33.47' carrying 20 bytes
# ipv4 packet from b'171.37.83.48' to b'217.178.92.19' carrying 20 bytes
# ipv4 packet from b'173.190.215.205' to b'214.161.154.208' carrying 20 bytes
# ipv4 packet from b'214.200.3.145' to b'221.224.59.49' carrying 20 bytes
# ipv4 packet from b'208.78.69.69' to b'215.46.70.217' carrying 20 bytes
# ipv4 packet from b'173.190.215.205' to b'214.161.154.208' carrying 20 bytes
# ipv4 packet from b'173.190.199.61' to b'209.61.49.65' carrying 42 bytes
# ipv4 packet from b'132.9.25.130' to b'203.106.142.236' carrying 20 bytes
# ipv4 packet from b'203.106.142.236' to b'132.9.25.130' carrying 20 bytes
# ipv4 packet from b'173.190.215.205' to b'214.161.154.208' carrying 20 bytes
# ipv4 packet from b'214.200.3.145' to b'193.47.22.8' carrying 32 bytes
# ipv4 packet from b'214.200.3.149' to b'214.165.185.38' carrying 20 bytes
# ipv4 packet from b'173.190.208.81' to b'215.15.152.211' carrying 20 bytes
# ipv4 packet from b'214.200.3.149' to b'214.170.80.226' carrying 20 bytes
# ipv4 packet from b'214.200.3.166' to b'193.18.31.242' carrying 20 bytes
# ipv4 packet from b'171.37.25.91' to b'193.146.53.193' carrying 20 bytes
# ipv4 packet from b'214.200.3.145' to b'193.47.22.8' carrying 32 bytes
# ipv4 packet from b'214.200.3.149' to b'214.170.80.226' carrying 20 bytes
# ipv4 packet from b'173.190.22.29' to b'130.163.216.202' carrying 20 bytes
# ipv4 packet from b'214.200.3.145' to b'221.224.59.49' carrying 20 bytes
# ipv4 packet from b'203.106.142.236' to b'132.9.25.130' carrying 20 bytes
# ipv4 packet from b'173.190.22.42' to b'214.162.23.108' carrying 20 bytes
# ipv4 packet from b'145.18.236.142' to b'173.190.216.101' carrying 20 bytes
# ipv4 packet from b'192.10.75.214' to b'132.47.219.143' carrying 20 bytes
# ipv4 packet from b'154.184.192.152' to b'132.9.33.47' carrying 20 bytes
# ipv4 packet from b'210.67.70.84' to b'173.190.76.54' carrying 20 bytes
# ipv4 packet from b'203.69.57.253' to b'173.190.210.146' carrying 24 bytes
# ipv4 packet from b'171.37.83.48' to b'211.67.197.107' carrying 20 bytes
# ipv4 packet from b'215.46.83.16' to b'192.154.14.110' carrying 20 bytes
# ipv4 packet from b'132.9.25.130' to b'203.106.142.236' carrying 20 bytes
# ipv4 packet from b'217.178.92.19' to b'132.2.6.52' carrying 20 bytes
# ipv4 packet from b'173.190.232.81' to b'215.15.157.18' carrying 20 bytes
# ipv4 packet from b'129.46.14.188' to b'217.178.92.240' carrying 20 bytes
# ipv4 packet from b'132.175.206.208' to b'193.144.60.240' carrying 20 bytes
# ipv4 packet from b'171.37.141.4' to b'221.156.101.233' carrying 20 bytes
# ipv4 packet from b'129.46.14.188' to b'217.178.92.240' carrying 20 bytes
# ipv4 packet from b'217.178.92.240' to b'132.47.146.91' carrying 20 bytes
# ipv4 packet from b'173.190.234.252' to b'214.172.42.65' carrying 20 bytes
# ipv4 packet from b'173.190.214.63' to b'221.206.196.238' carrying 20 bytes
# ipv4 packet from b'173.190.20.227' to b'138.106.80.83' carrying 20 bytes
# ipv4 packet from b'214.200.0.96' to b'193.235.219.61' carrying 20 bytes
# ipv4 packet from b'214.200.3.145' to b'193.235.47.12' carrying 20 bytes
# ipv4 packet from b'217.178.92.241' to b'132.47.196.169' carrying 20 bytes
# ipv4 packet from b'214.200.3.145' to b'193.235.47.12' carrying 20 bytes
# ipv4 packet from b'210.60.107.64' to b'173.190.214.63' carrying 20 bytes
# ipv4 packet from b'129.46.14.188' to b'217.178.92.240' carrying 20 bytes
# ipv4 packet from b'132.9.25.130' to b'203.106.142.236' carrying 20 bytes
# ipv4 packet from b'211.190.128.149' to b'173.190.98.214' carrying 40 bytes
# ipv4 packet from b'129.46.16.139' to b'210.60.113.16' carrying 20 bytes
# ipv4 packet from b'215.46.85.95' to b'193.71.46.181' carrying 20 bytes
# ipv4 packet from b'132.9.25.130' to b'203.106.142.236' carrying 20 bytes
# ipv4 packet from b'132.9.190.33' to b'203.113.220.40' carrying 20 bytes
# ipv4 packet from b'203.106.142.236' to b'132.9.25.130' carrying 20 bytes
# ipv4 packet from b'214.200.3.145' to b'221.224.59.49' carrying 20 bytes
# ipv4 packet from b'173.190.216.16' to b'210.15.154.38' carrying 20 bytes
# ipv4 packet from b'203.106.142.236' to b'132.9.25.130' carrying 20 bytes
# ipv4 packet from b'214.200.3.148' to b'214.171.62.45' carrying 20 bytes
# ipv4 packet from b'171.37.103.156' to b'217.44.249.91' carrying 20 bytes
# ipv4 packet from b'132.9.33.47' to b'211.38.58.124' carrying 20 bytes
# ipv4 packet from b'214.200.0.96' to b'193.235.219.61' carrying 20 bytes
# ipv4 packet from b'203.106.142.236' to b'132.47.134.53' carrying 20 bytes
# ipv4 packet from b'209.13.145.149' to b'173.190.215.139' carrying 8 bytes
# ipv4 packet from b'193.2.172.20' to b'173.190.216.96' carrying 20 bytes
# ipv4 packet from b'192.23.76.17' to b'221.133.178.44' carrying 20 bytes
# ipv4 packet from b'132.9.25.130' to b'203.106.142.236' carrying 20 bytes
# ipv4 packet from b'211.142.17.78' to b'132.47.209.22' carrying 20 bytes
# ipv4 packet from b'217.178.92.24' to b'132.47.196.169' carrying 24 bytes
# ipv4 packet from b'217.178.92.26' to b'132.47.146.91' carrying 8 bytes
# ipv4 packet from b'208.42.145.88' to b'173.190.211.18' carrying 20 bytes
# ipv4 packet from b'193.235.219.129' to b'132.47.220.4' carrying 24 bytes
# ipv4 packet from b'173.190.234.3' to b'217.72.251.124' carrying 20 bytes
# ipv4 packet from b'173.190.215.9' to b'193.171.154.61' carrying 42 bytes
# ipv4 packet from b'209.13.197.78' to b'173.190.221.45' carrying 28 bytes
# ipv4 packet from b'210.60.107.64' to b'173.190.214.63' carrying 20 bytes
# ipv4 packet from b'173.190.199.60' to b'171.93.250.105' carrying 20 bytes
# ipv4 packet from b'173.190.21.86' to b'174.60.243.242' carrying 32 bytes
# ipv4 packet from b'171.37.201.173' to b'193.103.67.174' carrying 20 bytes
# ipv4 packet from b'193.2.25.132' to b'132.2.142.219' carrying 20 bytes
# ipv4 packet from b'208.15.68.115' to b'132.47.222.66' carrying 8 bytes
# ipv4 packet from b'210.191.227.209' to b'173.190.22.155' carrying 20 bytes
# ipv4 packet from b'173.190.215.9' to b'215.131.139.173' carrying 20 bytes
# ipv4 packet from b'129.46.3.206' to b'220.44.134.86' carrying 20 bytes
# ipv4 packet from b'215.46.70.217' to b'208.78.69.69' carrying 20 bytes
# ipv4 packet from b'215.46.83.16' to b'192.154.14.110' carrying 20 bytes
# ipv4 packet from b'193.145.4.48' to b'132.2.136.225' carrying 20 bytes
# ipv4 packet from b'129.46.165.223' to b'59.36.81.47' carrying 20 bytes
# ipv4 packet from b'193.2.35.25' to b'132.47.192.111' carrying 20 bytes
# ipv4 packet from b'222.164.196.171' to b'132.2.92.24' carrying 20 bytes
# ipv4 packet from b'222.50.80.117' to b'215.46.68.32' carrying 20 bytes
# ipv4 packet from b'215.46.83.16' to b'192.154.14.110' carrying 20 bytes
# ipv4 packet from b'214.200.3.166' to b'209.155.33.16' carrying 20 bytes
# ipv4 packet from b'193.235.219.151' to b'173.190.214.63' carrying 20 bytes
# ipv4 packet from b'129.46.101.17' to b'193.153.53.109' carrying 36 bytes
# ipv4 packet from b'132.9.25.133' to b'9.38.174.174' carrying 20 bytes
# ipv4 packet from b'203.106.142.236' to b'132.9.25.130' carrying 20 bytes
# ipv4 packet from b'174.51.184.46' to b'132.47.209.22' carrying 20 bytes
# ipv4 packet from b'192.10.75.214' to b'132.47.219.143' carrying 20 bytes
# ipv4 packet from b'132.9.99.77' to b'193.144.60.240' carrying 20 bytes
# ipv4 packet from b'215.46.68.32' to b'222.50.80.117' carrying 20 bytes
# ipv4 packet from b'129.46.177.209' to b'221.129.127.32' carrying 20 bytes
# ipv4 packet from b'129.46.177.209' to b'221.129.127.32' carrying 20 bytes
# ipv4 packet from b'132.9.132.170' to b'208.1.64.214' carrying 24 bytes
# ipv4 packet from b'193.2.25.132' to b'132.47.192.71' carrying 20 bytes
# ipv4 packet from b'132.9.25.169' to b'193.2.25.132' carrying 20 bytes
# ipv4 packet from b'132.9.197.202' to b'203.113.53.74' carrying 8 bytes
# ipv4 packet from b'217.178.92.250' to b'132.9.190.38' carrying 20 bytes
# ipv4 packet from b'214.200.3.166' to b'192.22.84.12' carrying 20 bytes
# ipv4 packet from b'214.200.3.166' to b'192.64.114.66' carrying 20 bytes
# ipv4 packet from b'214.200.3.166' to b'192.64.114.66' carrying 20 bytes
# ipv4 packet from b'214.200.3.166' to b'214.172.149.149' carrying 20 bytes
# ipv4 packet from b'132.9.25.130' to b'203.106.142.236' carrying 20 bytes
# ipv4 packet from b'132.9.190.33' to b'203.113.220.40' carrying 20 bytes
# ipv4 packet from b'132.9.25.169' to b'193.2.25.132' carrying 20 bytes
# ipv4 packet from b'173.190.22.42' to b'214.172.149.150' carrying 20 bytes
# ipv4 packet from b'214.200.3.166' to b'192.8.179.254' carrying 20 bytes
# ipv4 packet from b'214.200.3.166' to b'192.8.179.254' carrying 20 bytes
# ipv4 packet from b'193.2.25.132' to b'132.47.192.71' carrying 20 bytes
# ipv4 packet from b'193.235.92.146' to b'173.190.21.86' carrying 40 bytes
# ipv4 packet from b'129.46.16.139' to b'210.60.113.16' carrying 20 bytes
# ipv4 packet from b'214.200.3.166' to b'193.18.31.242' carrying 20 bytes
# ipv4 packet from b'132.9.33.33' to b'154.56.77.118' carrying 8 bytes
# ipv4 packet from b'129.46.177.209' to b'221.129.127.32' carrying 20 bytes
# ipv4 packet from b'211.3.23.225' to b'173.190.198.112' carrying 20 bytes
# ipv4 packet from b'214.200.3.166' to b'217.178.92.250' carrying 24 bytes
# ipv4 packet from b'214.200.0.96' to b'193.235.219.61' carrying 20 bytes
# ipv4 packet from b'214.200.3.148' to b'214.171.62.45' carrying 20 bytes
# ipv4 packet from b'129.46.85.220' to b'215.46.69.99' carrying 20 bytes
# ipv4 packet from b'132.9.190.33' to b'203.113.220.40' carrying 20 bytes
# ipv4 packet from b'217.178.92.250' to b'132.2.200.64' carrying 20 bytes
# ipv4 packet from b'193.2.35.7' to b'173.190.234.149' carrying 20 bytes
# ipv4 packet from b'222.80.230.91' to b'173.190.210.196' carrying 20 bytes
# ipv4 packet from b'221.133.178.44' to b'192.23.76.17' carrying 20 bytes
# ipv4 packet from b'214.50.42.44' to b'208.15.68.77' carrying 8 bytes
# ipv4 packet from b'193.144.60.240' to b'173.190.214.63' carrying 20 bytes
# ipv4 packet from b'209.12.57.42' to b'132.2.6.184' carrying 20 bytes
# ipv4 packet from b'221.133.178.44' to b'192.23.76.17' carrying 20 bytes
# ipv4 packet from b'129.46.3.206' to b'220.44.134.80' carrying 20 bytes
# ipv4 packet from b'132.9.3.98' to b'193.130.154.58' carrying 20 bytes
# ipv4 packet from b'214.200.3.166' to b'148.77.81.127' carrying 20 bytes
# ipv4 packet from b'173.190.208.65' to b'211.148.216.250' carrying 8 bytes
# ipv4 packet from b'214.200.3.166' to b'217.130.51.55' carrying 24 bytes
# ipv4 packet from b'217.178.92.242' to b'132.21.63.73' carrying 20 bytes
# ipv4 packet from b'214.200.3.166' to b'209.222.238.106' carrying 20 bytes
# ipv4 packet from b'217.178.92.24' to b'132.47.196.169' carrying 20 bytes
# ipv4 packet from b'129.46.16.139' to b'210.60.113.16' carrying 20 bytes
# ipv4 packet from b'173.190.77.61' to b'209.48.201.190' carrying 20 bytes
# ipv4 packet from b'214.200.0.96' to b'193.235.219.61' carrying 20 bytes
# ipv4 packet from b'173.190.118.216' to b'217.205.144.201' carrying 32 bytes
# ipv4 packet from b'217.178.92.250' to b'132.47.196.169' carrying 20 bytes
# ipv4 packet from b'129.46.21.187' to b'193.235.219.128' carrying 20 bytes
# ipv4 packet from b'173.190.209.10' to b'210.97.250.120' carrying 20 bytes
# ipv4 packet from b'173.190.209.10' to b'210.97.250.120' carrying 20 bytes
# ipv4 packet from b'173.190.199.60' to b'145.19.117.64' carrying 20 bytes
# ipv4 packet from b'214.200.3.166' to b'192.8.179.254' carrying 20 bytes
# ipv4 packet from b'132.9.99.77' to b'193.144.60.240' carrying 20 bytes
# ipv4 packet from b'132.9.190.33' to b'203.113.220.40' carrying 20 bytes
# ipv4 packet from b'217.178.92.24' to b'132.47.196.169' carrying 20 bytes
# ipv4 packet from b'173.190.208.85' to b'134.50.232.246' carrying 20 bytes
# ipv4 packet from b'132.9.99.77' to b'193.144.60.240' carrying 20 bytes
# ipv4 packet from b'129.46.3.206' to b'220.44.134.86' carrying 20 bytes
# ipv4 packet from b'214.200.0.96' to b'193.235.219.61' carrying 20 bytes
# ipv4 packet from b'129.46.16.139' to b'210.60.113.16' carrying 20 bytes
# ipv4 packet from b'214.200.3.166' to b'217.178.92.67' carrying 20 bytes
# ipv4 packet from b'214.200.9.47' to b'132.25.40.214' carrying 8 bytes
# ipv4 packet from b'193.2.29.66' to b'132.47.171.162' carrying 20 bytes
# ipv4 packet from b'209.61.52.144' to b'173.190.77.32' carrying 28 bytes
# ipv4 packet from b'193.86.162.111' to b'173.190.193.1' carrying 20 bytes
# ipv4 packet from b'222.80.230.91' to b'173.190.210.196' carrying 20 bytes
# ipv4 packet from b'129.46.3.206' to b'220.44.134.80' carrying 20 bytes
# ipv4 packet from b'214.200.3.148' to b'193.235.92.146' carrying 32 bytes
# ipv4 packet from b'214.200.0.96' to b'193.235.219.61' carrying 20 bytes
# ipv4 packet from b'214.200.3.148' to b'193.235.92.146' carrying 32 bytes
# ipv4 packet from b'193.2.25.132' to b'132.47.134.33' carrying 20 bytes
# ipv4 packet from b'171.37.83.48' to b'217.178.92.19' carrying 20 bytes
# ipv4 packet from b'173.190.22.42' to b'214.172.149.150' carrying 20 bytes
# ipv4 packet from b'129.46.16.139' to b'210.60.113.16' carrying 20 bytes
# ipv4 packet from b'210.209.223.10' to b'173.190.209.10' carrying 20 bytes
# ipv4 packet from b'129.46.165.26' to b'130.141.130.229' carrying 20 bytes
# ipv4 packet from b'215.46.83.16' to b'192.154.14.110' carrying 20 bytes
# ipv4 packet from b'203.106.142.236' to b'132.9.25.130' carrying 20 bytes
# ipv4 packet from b'214.68.49.213' to b'173.190.198.112' carrying 20 bytes
# ipv4 packet from b'193.235.219.144' to b'173.190.214.63' carrying 20 bytes
# ipv4 packet from b'173.190.118.216' to b'146.162.51.125' carrying 20 bytes
# ipv4 packet from b'129.46.3.206' to b'220.44.134.88' carrying 20 bytes
# ipv4 packet from b'132.9.25.130' to b'203.106.142.236' carrying 20 bytes
# ipv4 packet from b'132.9.25.130' to b'203.106.142.236' carrying 20 bytes
# ipv4 packet from b'9.38.174.174' to b'132.9.25.133' carrying 20 bytes
# ipv4 packet from b'129.46.170.232' to b'217.130.48.127' carrying 24 bytes
# ipv4 packet from b'222.164.196.203' to b'132.2.92.24' carrying 20 bytes
# ipv4 packet from b'173.190.22.29' to b'221.215.163.229' carrying 20 bytes
# ipv4 packet from b'173.190.234.9' to b'215.196.48.8' carrying 20 bytes
# ipv4 packet from b'173.190.214.95' to b'209.13.145.149' carrying 8 bytes
# ipv4 packet from b'173.190.218.131' to b'129.128.94.132' carrying 20 bytes
# ipv4 packet from b'173.190.218.131' to b'193.235.92.146' carrying 40 bytes
# ipv4 packet from b'129.46.101.17' to b'193.153.53.109' carrying 36 bytes
# ipv4 packet from b'217.178.92.241' to b'132.47.196.169' carrying 20 bytes
# ipv4 packet from b'129.46.14.188' to b'217.178.92.240' carrying 20 bytes
# ipv4 packet from b'130.210.135.237' to b'132.47.216.193' carrying 20 bytes
# ipv4 packet from b'171.37.25.91' to b'193.146.53.202' carrying 20 bytes
# ipv4 packet from b'214.50.42.44' to b'208.15.71.64' carrying 8 bytes
# ipv4 packet from b'193.2.25.132' to b'132.47.192.71' carrying 20 bytes
# ipv4 packet from b'214.165.198.240' to b'173.190.232.85' carrying 20 bytes
# ipv4 packet from b'192.154.170.2' to b'173.190.193.1' carrying 20 bytes
# ipv4 packet from b'193.2.29.66' to b'132.47.192.71' carrying 20 bytes
# ipv4 packet from b'173.190.232.81' to b'215.15.157.18' carrying 20 bytes
# ipv4 packet from b'132.9.190.33' to b'203.113.220.40' carrying 20 bytes
# ipv4 packet from b'203.106.142.236' to b'132.9.25.130' carrying 20 bytes
# ipv4 packet from b'132.9.190.38' to b'217.178.92.250' carrying 20 bytes
# ipv4 packet from b'173.190.232.81' to b'215.15.157.18' carrying 20 bytes
# ipv4 packet from b'173.190.21.86' to b'174.60.243.242' carrying 32 bytes
# ipv4 packet from b'171.37.103.156' to b'216.99.88.147' carrying 20 bytes
# ipv4 packet from b'203.106.142.236' to b'132.47.134.53' carrying 20 bytes
# ipv4 packet from b'129.46.165.223' to b'59.36.81.47' carrying 20 bytes
# ipv4 packet from b'21.184.161.43' to b'134.50.232.246' carrying 20 bytes
# ipv4 packet from b'173.190.215.205' to b'214.161.154.208' carrying 20 bytes
# ipv4 packet from b'214.200.3.149' to b'214.170.80.226' carrying 20 bytes
# ipv4 packet from b'214.200.3.148' to b'214.179.15.13' carrying 20 bytes
# ipv4 packet from b'132.9.99.11' to b'210.60.107.64' carrying 20 bytes
# ipv4 packet from b'214.200.3.161' to b'211.21.188.175' carrying 20 bytes
# ipv4 packet from b'203.106.142.236' to b'132.9.25.130' carrying 20 bytes
# ipv4 packet from b'129.46.12.19' to b'203.106.142.236' carrying 20 bytes
# ipv4 packet from b'215.46.83.16' to b'192.154.14.110' carrying 20 bytes
# ipv4 packet from b'214.50.42.44' to b'211.210.13.178' carrying 20 bytes
# ipv4 packet from b'214.50.42.44' to b'208.15.68.67' carrying 8 bytes
# ipv4 packet from b'211.38.58.124' to b'132.9.33.47' carrying 20 bytes
# ipv4 packet from b'132.9.25.130' to b'203.106.142.236' carrying 20 bytes
# ipv4 packet from b'215.46.68.32' to b'222.10.167.200' carrying 20 bytes
# ipv4 packet from b'215.46.83.16' to b'192.154.14.110' carrying 20 bytes
# ipv4 packet from b'193.235.239.202' to b'221.133.178.46' carrying 32 bytes
# ipv4 packet from b'171.37.83.48' to b'211.67.197.107' carrying 20 bytes
# ipv4 packet from b'203.106.142.236' to b'132.9.25.130' carrying 20 bytes
# ipv4 packet from b'173.190.199.61' to b'209.61.49.100' carrying 20 bytes
# ipv4 packet from b'193.2.25.132' to b'132.2.142.219' carrying 20 bytes
# ipv4 packet from b'129.46.86.222' to b'203.113.53.77' carrying 20 bytes
# ipv4 packet from b'193.2.35.1' to b'132.9.33.37' carrying 20 bytes
# ipv4 packet from b'192.23.76.82' to b'221.133.178.44' carrying 20 bytes
# ipv4 packet from b'209.61.49.65' to b'173.190.199.61' carrying 28 bytes
# ipv4 packet from b'216.179.46.254' to b'132.47.128.123' carrying 20 bytes
# ipv4 packet from b'221.50.98.125' to b'129.47.67.140' carrying 20 bytes
# ipv4 packet from b'129.213.115.194' to b'132.9.115.166' carrying 8 bytes
# ipv4 packet from b'214.50.42.44' to b'208.15.68.73' carrying 8 bytes
# ipv4 packet from b'193.194.142.138' to b'173.190.22.45' carrying 40 bytes
# ipv4 packet from b'132.9.33.37' to b'193.2.35.1' carrying 20 bytes
# ipv4 packet from b'132.9.25.130' to b'203.106.142.236' carrying 20 bytes
# ipv4 packet from b'214.200.3.166' to b'192.8.179.254' carrying 20 bytes
# ipv4 packet from b'132.175.206.208' to b'193.68.97.38' carrying 32 bytes
# ipv4 packet from b'214.200.3.166' to b'192.8.179.254' carrying 20 bytes
# ipv4 packet from b'193.235.219.150' to b'132.21.33.89' carrying 20 bytes
# ipv4 packet from b'210.15.154.38' to b'173.190.216.16' carrying 20 bytes
# ipv4 packet from b'214.50.42.44' to b'208.15.71.73' carrying 8 bytes
# ipv4 packet from b'132.9.99.11' to b'210.60.107.64' carrying 28 bytes
# ipv4 packet from b'132.9.190.33' to b'203.113.220.40' carrying 20 bytes
# ipv4 packet from b'171.37.141.4' to b'221.156.101.233' carrying 20 bytes
# ipv4 packet from b'193.2.25.132' to b'132.2.92.145' carrying 20 bytes
# ipv4 packet from b'173.190.198.112' to b'214.172.42.23' carrying 20 bytes
# ipv4 packet from b'214.50.42.44' to b'193.225.133.106' carrying 32 bytes
# ipv4 packet from b'171.37.83.48' to b'211.67.197.107' carrying 20 bytes
# ipv4 packet from b'222.164.196.171' to b'132.2.92.24' carrying 20 bytes
# ipv4 packet from b'129.46.86.222' to b'203.113.53.77' carrying 20 bytes
# ipv4 packet from b'129.46.86.222' to b'203.113.53.77' carrying 20 bytes
# ipv4 packet from b'173.190.210.215' to b'210.8.90.23' carrying 20 bytes
# ipv4 packet from b'173.190.77.32' to b'209.61.52.144' carrying 20 bytes
# ipv4 packet from b'217.178.92.250' to b'132.47.196.169' carrying 20 bytes
# ipv4 packet from b'215.175.19.246' to b'132.47.198.78' carrying 20 bytes
# ipv4 packet from b'132.9.99.77' to b'193.144.60.240' carrying 20 bytes
# ipv4 packet from b'214.200.3.148' to b'214.6.7.45' carrying 42 bytes
# ipv4 packet from b'129.46.86.222' to b'203.113.53.76' carrying 24 bytes
# ipv4 packet from b'203.106.142.236' to b'132.9.25.130' carrying 20 bytes
# ipv4 packet from b'214.200.3.166' to b'210.164.192.72' carrying 20 bytes
# ipv4 packet from b'214.200.3.166' to b'210.164.192.72' carrying 20 bytes
# ipv4 packet from b'214.200.3.166' to b'217.178.92.250' carrying 20 bytes
# ipv4 packet from b'132.9.33.47' to b'211.38.58.124' carrying 20 bytes
# ipv4 packet from b'173.190.193.93' to b'222.21.97.188' carrying 20 bytes
# ipv4 packet from b'21.184.161.43' to b'134.50.232.246' carrying 20 bytes
# ipv4 packet from b'193.160.177.19' to b'215.46.83.16' carrying 20 bytes
# ipv4 packet from b'214.200.3.148' to b'128.30.87.91' carrying 32 bytes
# ipv4 packet from b'214.200.3.166' to b'217.178.92.250' carrying 20 bytes
# ipv4 packet from b'174.60.243.242' to b'173.190.21.86' carrying 32 bytes
# ipv4 packet from b'132.175.206.208' to b'193.68.97.38' carrying 32 bytes
# ipv4 packet from b'221.133.178.46' to b'193.235.239.202' carrying 32 bytes
# ipv4 packet from b'132.9.25.130' to b'203.106.142.236' carrying 20 bytes
# ipv4 packet from b'221.133.178.46' to b'193.235.239.202' carrying 32 bytes
# ipv4 packet from b'129.46.21.60' to b'193.235.219.129' carrying 20 bytes
# ipv4 packet from b'129.46.90.71' to b'203.106.142.236' carrying 20 bytes
# ipv4 packet from b'193.84.221.118' to b'132.9.25.169' carrying 20 bytes
# ipv4 packet from b'214.200.3.166' to b'193.235.219.146' carrying 20 bytes
# ipv4 packet from b'132.9.190.40' to b'217.178.92.250' carrying 20 bytes
# ipv4 packet from b'173.190.22.42' to b'223.27.201.14' carrying 20 bytes
# ipv4 packet from b'203.106.142.236' to b'132.9.25.130' carrying 20 bytes
# ipv4 packet from b'129.46.177.26' to b'148.77.180.160' carrying 20 bytes
# ipv4 packet from b'211.155.62.68' to b'173.190.76.133' carrying 20 bytes
# ipv4 packet from b'193.2.35.25' to b'132.47.192.111' carrying 20 bytes
# ipv4 packet from b'129.46.101.17' to b'171.189.177.235' carrying 36 bytes
# ipv4 packet from b'220.143.5.184' to b'132.47.213.118' carrying 20 bytes
# ipv4 packet from b'193.130.167.169' to b'132.2.136.47' carrying 20 bytes
# ipv4 packet from b'217.72.251.124' to b'173.190.234.3' carrying 20 bytes
# ipv4 packet from b'217.72.251.124' to b'173.190.210.215' carrying 20 bytes
# ipv4 packet from b'129.46.21.60' to b'193.235.219.130' carrying 28 bytes
# ipv4 packet from b'214.200.3.166' to b'209.222.238.106' carrying 20 bytes
# ipv4 packet from b'214.200.3.166' to b'217.130.51.55' carrying 20 bytes
# ipv4 packet from b'130.210.135.237' to b'132.47.216.193' carrying 20 bytes
# ipv4 packet from b'132.9.25.169' to b'193.84.221.118' carrying 20 bytes
# ipv4 packet from b'132.9.25.130' to b'203.106.142.236' carrying 20 bytes
# ipv4 packet from b'129.46.177.26' to b'148.77.162.168' carrying 20 bytes
# ipv4 packet from b'129.46.101.17' to b'214.65.158.4' carrying 8 bytes
# ipv4 packet from b'203.106.142.236' to b'132.9.25.130' carrying 20 bytes
# ipv4 packet from b'214.200.3.166' to b'217.130.51.55' carrying 20 bytes
# ipv4 packet from b'214.200.3.148' to b'214.179.15.13' carrying 20 bytes
# ipv4 packet from b'217.178.92.24' to b'132.47.196.169' carrying 20 bytes
# ipv4 packet from b'214.200.3.166' to b'148.77.81.127' carrying 20 bytes
# ipv4 packet from b'171.37.145.32' to b'193.2.25.132' carrying 20 bytes
# ipv4 packet from b'132.9.25.133' to b'9.38.174.174' carrying 20 bytes
# ipv4 packet from b'133.103.186.172' to b'132.9.229.24' carrying 20 bytes
# ipv4 packet from b'209.13.197.103' to b'132.47.132.107' carrying 24 bytes
# ipv4 packet from b'132.9.99.77' to b'193.144.60.240' carrying 20 bytes
# ipv4 packet from b'193.2.25.132' to b'132.47.192.71' carrying 20 bytes
# ipv4 packet from b'129.46.16.139' to b'210.60.113.16' carrying 20 bytes
# ipv4 packet from b'203.106.142.236' to b'132.2.200.72' carrying 20 bytes
# ipv4 packet from b'214.200.3.166' to b'192.8.179.254' carrying 20 bytes
# ipv4 packet from b'215.77.35.133' to b'132.47.134.53' carrying 8 bytes
# ipv4 packet from b'215.77.35.133' to b'132.47.134.53' carrying 8 bytes
# ipv4 packet from b'203.106.142.236' to b'132.9.25.130' carrying 20 bytes
# ipv4 packet from b'129.46.3.206' to b'220.44.134.86' carrying 20 bytes
# ipv4 packet from b'209.155.154.206' to b'132.2.195.112' carrying 20 bytes
# ipv4 packet from b'173.190.211.18' to b'208.42.145.88' carrying 20 bytes
# ipv4 packet from b'214.200.3.166' to b'209.222.238.106' carrying 20 bytes
# ipv4 packet from b'132.9.25.130' to b'203.106.142.236' carrying 20 bytes
# ipv4 packet from b'193.235.219.146' to b'132.21.72.123' carrying 20 bytes
# ipv4 packet from b'132.9.25.130' to b'203.106.142.236' carrying 20 bytes
# ipv4 packet from b'132.9.25.130' to b'203.106.142.236' carrying 20 bytes
# ipv4 packet from b'215.46.83.16' to b'192.154.14.110' carrying 20 bytes
# ipv4 packet from b'173.190.22.42' to b'193.235.92.146' carrying 20 bytes
# ipv4 packet from b'214.200.3.161' to b'221.168.249.219' carrying 20 bytes
# ipv4 packet from b'193.71.46.181' to b'215.46.85.95' carrying 20 bytes
# ipv4 packet from b'132.9.99.11' to b'210.60.107.64' carrying 20 bytes
# ipv4 packet from b'174.60.243.242' to b'173.190.21.86' carrying 32 bytes
# ipv4 packet from b'214.200.3.161' to b'211.184.253.180' carrying 20 bytes
# ipv4 packet from b'214.200.3.161' to b'211.184.253.180' carrying 20 bytes
# ipv4 packet from b'209.61.52.144' to b'173.190.77.32' carrying 20 bytes
# ipv4 packet from b'217.178.92.24' to b'132.47.134.78' carrying 20 bytes
# ipv4 packet from b'173.190.210.219' to b'216.132.241.236' carrying 32 bytes
# ipv4 packet from b'173.190.198.79' to b'174.171.18.51' carrying 20 bytes
# ipv4 packet from b'173.190.153.114' to b'221.215.163.229' carrying 20 bytes
# ipv4 packet from b'173.190.198.79' to b'174.171.18.51' carrying 20 bytes
# ipv4 packet from b'193.2.35.1' to b'132.9.33.37' carrying 20 bytes
# ipv4 packet from b'211.109.62.68' to b'132.47.171.165' carrying 20 bytes
# ipv4 packet from b'173.190.209.10' to b'210.209.223.10' carrying 20 bytes
# ipv4 packet from b'173.190.209.40' to b'209.79.87.190' carrying 20 bytes
# ipv4 packet from b'208.15.68.87' to b'132.47.134.148' carrying 8 bytes
# ipv4 packet from b'59.81.168.178' to b'132.21.49.200' carrying 8 bytes
# ipv4 packet from b'154.56.77.118' to b'132.9.33.33' carrying 36 bytes
# ipv4 packet from b'214.162.25.81' to b'173.190.76.132' carrying 20 bytes
# ipv4 packet from b'193.171.154.61' to b'173.190.215.9' carrying 42 bytes
# ipv4 packet from b'193.235.92.146' to b'173.190.218.131' carrying 40 bytes
# ipv4 packet from b'173.190.214.63' to b'210.60.107.64' carrying 20 bytes
# ipv4 packet from b'173.190.214.63' to b'210.60.107.64' carrying 20 bytes
# ipv4 packet from b'173.190.214.60' to b'209.13.145.149' carrying 8 bytes
# ipv4 packet from b'173.190.199.61' to b'209.61.49.65' carrying 42 bytes
# ipv4 packet from b'132.9.33.37' to b'193.2.35.1' carrying 20 bytes
# ipv4 packet from b'173.190.21.86' to b'174.60.243.242' carrying 32 bytes
# ipv4 packet from b'193.144.60.240' to b'132.2.92.145' carrying 20 bytes
# ipv4 packet from b'215.46.68.0' to b'215.46.68.5' carrying 20 bytes
# ipv4 packet from b'209.48.201.190' to b'173.190.77.61' carrying 20 bytes
# ipv4 packet from b'221.241.162.92' to b'221.133.178.35' carrying 20 bytes
# ipv4 packet from b'193.235.92.146' to b'173.190.218.131' carrying 40 bytes
# ipv4 packet from b'209.13.145.149' to b'173.190.214.95' carrying 8 bytes
# ipv4 packet from b'214.200.3.149' to b'214.165.185.38' carrying 20 bytes
# ipv4 packet from b'129.46.170.232' to b'217.130.48.127' carrying 20 bytes
# ipv4 packet from b'132.9.99.11' to b'210.60.107.64' carrying 20 bytes
# ipv4 packet from b'209.61.49.100' to b'173.190.199.61' carrying 20 bytes
# ipv4 packet from b'132.9.99.11' to b'210.60.107.64' carrying 20 bytes
# ipv4 packet from b'129.46.170.232' to b'217.130.48.127' carrying 20 bytes
# ipv4 packet from b'129.46.14.188' to b'217.178.92.240' carrying 20 bytes
# ipv4 packet from b'129.46.165.223' to b'59.36.81.47' carrying 20 bytes
# ipv4 packet from b'192.10.75.214' to b'132.47.219.143' carrying 20 bytes
# ipv4 packet from b'208.42.145.88' to b'173.190.211.18' carrying 20 bytes
# ipv4 packet from b'130.141.130.229' to b'129.46.165.26' carrying 20 bytes
# ipv4 packet from b'211.229.244.41' to b'132.47.192.27' carrying 20 bytes
# ipv4 packet from b'215.46.69.101' to b'193.146.53.202' carrying 20 bytes
# ipv4 packet from b'214.200.3.166' to b'148.77.81.127' carrying 20 bytes
# ipv4 packet from b'173.190.232.85' to b'214.172.149.28' carrying 20 bytes
# ipv4 packet from b'214.200.3.166' to b'211.51.72.111' carrying 20 bytes
# ipv4 packet from b'129.46.12.19' to b'203.106.142.236' carrying 20 bytes
# ipv4 packet from b'203.106.142.236' to b'132.9.25.130' carrying 20 bytes
# ipv4 packet from b'173.190.232.85' to b'214.172.149.28' carrying 20 bytes
# ipv4 packet from b'215.46.83.16' to b'192.154.14.110' carrying 20 bytes
# ipv4 packet from b'214.193.100.241' to b'211.69.166.193' carrying 20 bytes
# ipv4 packet from b'132.9.229.144' to b'193.235.219.128' carrying 28 bytes
# ipv4 packet from b'129.46.165.26' to b'221.152.130.159' carrying 20 bytes
# ipv4 packet from b'203.106.142.236' to b'132.9.25.130' carrying 20 bytes
# ipv4 packet from b'173.190.232.85' to b'214.172.149.28' carrying 20 bytes
# ipv4 packet from b'215.46.83.16' to b'192.154.14.110' carrying 20 bytes
# ipv4 packet from b'129.46.86.222' to b'203.113.53.76' carrying 20 bytes
# ipv4 packet from b'214.200.3.166' to b'192.8.179.254' carrying 20 bytes
# ipv4 packet from b'214.200.3.166' to b'192.8.179.254' carrying 20 bytes
# ipv4 packet from b'129.46.86.222' to b'203.113.53.76' carrying 20 bytes
# ipv4 packet from b'129.46.3.206' to b'220.44.134.80' carrying 20 bytes
# ipv4 packet from b'193.84.221.118' to b'132.9.25.169' carrying 20 bytes
# ipv4 packet from b'129.46.86.222' to b'203.113.53.76' carrying 20 bytes
# ipv4 packet from b'215.175.19.246' to b'132.47.198.78' carrying 20 bytes
# ipv4 packet from b'173.190.232.85' to b'214.172.149.28' carrying 20 bytes
# ipv4 packet from b'129.46.177.209' to b'221.129.127.32' carrying 20 bytes
# ipv4 packet from b'222.164.196.171' to b'132.2.92.24' carrying 20 bytes
# ipv4 packet from b'192.10.75.214' to b'132.47.219.143' carrying 20 bytes
# ipv4 packet from b'192.23.76.17' to b'221.133.178.44' carrying 20 bytes
# ipv4 packet from b'173.190.232.85' to b'214.172.149.28' carrying 20 bytes
# ipv4 packet from b'132.9.190.33' to b'203.113.220.40' carrying 20 bytes
# ipv4 packet from b'9.38.174.174' to b'132.9.25.133' carrying 20 bytes

# %%
# A more detailed summary of the packets
packets.sessions()
# Out:
# {'TCP 193.235.219.150:80 > 132.2.92.145:1813': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 215.46.69.99:22 > 129.46.85.220:1023': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'ICMP 214.50.42.44 > 208.15.71.88 type=3 code=3 id=None': <PacketList: TCP:0 UDP:0 ICMP:1 Other:0>,
#  'TCP 132.9.99.11:1421 > 210.60.107.64:80': <PacketList: TCP:7 UDP:0 ICMP:0 Other:0>,
#  'TCP 203.106.142.236:80 > 132.9.25.130:2618': <PacketList: TCP:3 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.25.169:3829 > 193.2.25.132:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.190.38:1113 > 217.178.92.250:80': <PacketList: TCP:3 UDP:0 ICMP:0 Other:0>,
#  'TCP 211.38.58.124:80 > 132.9.33.47:57400': <PacketList: TCP:3 UDP:0 ICMP:0 Other:0>,
#  'TCP 171.37.83.48:5103 > 217.178.92.19:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.215.205:4533 > 214.161.154.208:25': <PacketList: TCP:4 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.145:4950 > 221.224.59.49:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 208.78.69.69:80 > 215.46.70.217:34766': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.199.61:1075 > 209.61.49.65:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.25.130:2618 > 203.106.142.236:80': <PacketList: TCP:3 UDP:0 ICMP:0 Other:0>,
#  'TCP 203.106.142.236:80 > 132.9.25.130:2441': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.145:1043 > 193.47.22.8:80': <PacketList: TCP:3 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.149:4855 > 214.165.185.38:25': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.208.81:2359 > 215.15.152.211:25': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.149:4774 > 214.170.80.226:25': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.166:47309 > 193.18.31.242:80': <PacketList: TCP:8 UDP:0 ICMP:0 Other:0>,
#  'UDP 171.37.25.91:3058 > 193.146.53.193:53': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 173.190.22.29:25 > 130.163.216.202:1419': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.145:4990 > 221.224.59.49:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 203.106.142.236:80 > 132.9.25.130:2569': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.22.42:25 > 214.162.23.108:2109': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 145.18.236.142:2141 > 173.190.216.101:25': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 192.10.75.214:80 > 132.47.219.143:2475': <PacketList: TCP:4 UDP:0 ICMP:0 Other:0>,
#  'TCP 154.184.192.152:80 > 132.9.33.47:58983': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 210.67.70.84:60572 > 173.190.76.54:25': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 203.69.57.253:20 > 173.190.210.146:1252': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 171.37.83.48:5061 > 211.67.197.107:80': <PacketList: TCP:6 UDP:0 ICMP:0 Other:0>,
#  'TCP 215.46.83.16:64302 > 192.154.14.110:80': <PacketList: TCP:13 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.25.130:2441 > 203.106.142.236:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 217.178.92.19:80 > 132.2.6.52:20418': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.232.81:20 > 215.15.157.18:3786': <PacketList: TCP:3 UDP:0 ICMP:0 Other:0>,
#  'TCP 129.46.14.188:1717 > 217.178.92.240:80': <PacketList: TCP:7 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.175.206.208:2148 > 193.144.60.240:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 171.37.141.4:53 > 221.156.101.233:53': <PacketList: TCP:0 UDP:2 ICMP:0 Other:0>,
#  'TCP 217.178.92.240:80 > 132.47.146.91:2011': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.234.252:110 > 214.172.42.65:3330': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.214.63:3513 > 221.206.196.238:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 173.190.20.227:53 > 138.106.80.83:53': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 214.200.0.96:2051 > 193.235.219.61:80': <PacketList: TCP:6 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.145:4937 > 193.235.47.12:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 217.178.92.241:80 > 132.47.196.169:61334': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 210.60.107.64:80 > 173.190.214.63:5207': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.25.130:2574 > 203.106.142.236:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 211.190.128.149:80 > 173.190.98.214:3792': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 129.46.16.139:1962 > 210.60.113.16:80': <PacketList: TCP:6 UDP:0 ICMP:0 Other:0>,
#  'TCP 215.46.85.95:5061 > 193.71.46.181:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.25.130:2615 > 203.106.142.236:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.190.33:1150 > 203.113.220.40:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 203.106.142.236:80 > 132.9.25.130:2420': <PacketList: TCP:3 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.216.16:1697 > 210.15.154.38:8888': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 203.106.142.236:80 > 132.9.25.130:2615': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.148:2044 > 214.171.62.45:25': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'UDP 171.37.103.156:53 > 217.44.249.91:53': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 132.9.33.47:57400 > 211.38.58.124:80': <PacketList: TCP:3 UDP:0 ICMP:0 Other:0>,
#  'TCP 203.106.142.236:80 > 132.47.134.53:61003': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'ICMP 209.13.145.149 > 173.190.215.139 type=0 code=0 id=0x100': <PacketList: TCP:0 UDP:0 ICMP:1 Other:0>,
#  'TCP 193.2.172.20:31603 > 173.190.216.96:25': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 192.23.76.17:10484 > 221.133.178.44:6669': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 211.142.17.78:80 > 132.47.209.22:63648': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 217.178.92.24:80 > 132.47.196.169:61398': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'ICMP 217.178.92.26 > 132.47.146.91 type=0 code=0 id=0x200': <PacketList: TCP:0 UDP:0 ICMP:2 Other:0>,
#  'TCP 208.42.145.88:1931 > 173.190.211.18:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 193.235.219.129:80 > 132.47.220.4:2588': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.234.3:1822 > 217.72.251.124:4604': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.215.9:4771 > 193.171.154.61:6667': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 209.13.197.78:80 > 173.190.221.45:4000': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 173.190.199.60:3292 > 171.93.250.105:53': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 173.190.21.86:25 > 174.60.243.242:2652': <PacketList: TCP:3 UDP:0 ICMP:0 Other:0>,
#  'TCP 171.37.201.173:1119 > 193.103.67.174:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 193.2.25.132:80 > 132.2.142.219:4902': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'UDP 208.15.68.115:4000 > 132.47.222.66:64733': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'UDP 210.191.227.209:53 > 173.190.22.155:1029': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 173.190.215.9:1080 > 215.131.139.173:1108': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 129.46.3.206:1383 > 220.44.134.86:80': <PacketList: TCP:5 UDP:0 ICMP:0 Other:0>,
#  'TCP 215.46.70.217:34766 > 208.78.69.69:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 193.145.4.48:80 > 132.2.136.225:61123': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 129.46.165.223:1582 > 59.36.81.47:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 193.2.35.25:47443 > 132.47.192.111:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 222.164.196.171:8080 > 132.2.92.24:1966': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'UDP 222.50.80.117:53 > 215.46.68.32:53': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 214.200.3.166:47178 > 209.155.33.16:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 193.235.219.151:80 > 173.190.214.63:5213': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'ICMP 129.46.101.17 > 193.153.53.109 type=3 code=3 id=None': <PacketList: TCP:0 UDP:0 ICMP:2 Other:0>,
#  'TCP 132.9.25.133:2365 > 9.38.174.174:81': <PacketList: TCP:3 UDP:0 ICMP:0 Other:0>,
#  'TCP 203.106.142.236:80 > 132.9.25.130:2531': <PacketList: TCP:3 UDP:0 ICMP:0 Other:0>,
#  'TCP 174.51.184.46:80 > 132.47.209.22:63665': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.99.77:1128 > 193.144.60.240:80': <PacketList: TCP:4 UDP:0 ICMP:0 Other:0>,
#  'UDP 215.46.68.32:53 > 222.50.80.117:53': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 129.46.177.209:2202 > 221.129.127.32:17309': <PacketList: TCP:4 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.132.170:1857 > 208.1.64.214:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 193.2.25.132:80 > 132.47.192.71:2781': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.25.169:3838 > 193.2.25.132:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'ICMP 132.9.197.202 > 203.113.53.74 type=8 code=0 id=0x100': <PacketList: TCP:0 UDP:0 ICMP:1 Other:0>,
#  'TCP 217.178.92.250:80 > 132.9.190.38:1113': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.166:47293 > 192.22.84.12:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.166:38093 > 192.64.114.66:80': <PacketList: TCP:4 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.166:47247 > 214.172.149.149:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.25.130:2569 > 203.106.142.236:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.190.33:1160 > 203.113.220.40:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.22.42:25 > 214.172.149.150:14641': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.166:46074 > 192.8.179.254:80': <PacketList: TCP:11 UDP:0 ICMP:0 Other:0>,
#  'TCP 193.2.25.132:80 > 132.47.192.71:2735': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 193.235.92.146:25 > 173.190.21.86:3077': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 129.46.16.139:1961 > 210.60.113.16:80': <PacketList: TCP:4 UDP:0 ICMP:0 Other:0>,
#  'UDP 132.9.33.33:7001 > 154.56.77.118:7003': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 211.3.23.225:80 > 173.190.198.112:3416': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.166:47314 > 217.178.92.250:80': <PacketList: TCP:4 UDP:0 ICMP:0 Other:0>,
#  'TCP 129.46.85.220:1023 > 215.46.69.99:22': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.190.33:1122 > 203.113.220.40:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 217.178.92.250:80 > 132.2.200.64:3077': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 193.2.35.7:46490 > 173.190.234.149:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 222.80.230.91:52418 > 173.190.210.196:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 221.133.178.44:6669 > 192.23.76.17:10484': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'UDP 214.50.42.44:50592 > 208.15.68.77:4000': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 193.144.60.240:80 > 173.190.214.63:5200': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 209.12.57.42:53 > 132.2.6.184:47123': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 129.46.3.206:1395 > 220.44.134.80:80': <PacketList: TCP:5 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.3.98:1599 > 193.130.154.58:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.166:47272 > 148.77.81.127:80': <PacketList: TCP:5 UDP:0 ICMP:0 Other:0>,
#  'ICMP 173.190.208.65 > 211.148.216.250 type=8 code=0 id=0xc045': <PacketList: TCP:0 UDP:0 ICMP:1 Other:0>,
#  'TCP 214.200.3.166:47336 > 217.130.51.55:80': <PacketList: TCP:5 UDP:0 ICMP:0 Other:0>,
#  'TCP 217.178.92.242:80 > 132.21.63.73:1632': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.166:47335 > 209.222.238.106:80': <PacketList: TCP:3 UDP:0 ICMP:0 Other:0>,
#  'TCP 217.178.92.24:80 > 132.47.196.169:61397': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.77.61:64002 > 209.48.201.190:7000': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.118.216:4634 > 217.205.144.201:6667': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 217.178.92.250:80 > 132.47.196.169:61352': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 129.46.21.187:1647 > 193.235.219.128:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.209.10:2604 > 210.97.250.120:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'UDP 173.190.199.60:3292 > 145.19.117.64:53': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 132.9.99.77:1133 > 193.144.60.240:80': <PacketList: TCP:4 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.190.33:1167 > 203.113.220.40:80': <PacketList: TCP:3 UDP:0 ICMP:0 Other:0>,
#  'TCP 217.178.92.24:80 > 132.47.196.169:61372': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.208.85:2897 > 134.50.232.246:113': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.166:47271 > 217.178.92.67:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 214.200.9.47:520 > 132.25.40.214:520': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 193.2.29.66:80 > 132.47.171.162:62306': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 209.61.52.144:3128 > 173.190.77.32:2873': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 193.86.162.111:7000 > 173.190.193.1:62865': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.148:1955 > 193.235.92.146:25': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 193.2.25.132:80 > 132.47.134.33:3690': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 210.209.223.10:80 > 173.190.209.10:2874': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 129.46.165.26:53 > 130.141.130.229:53': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 203.106.142.236:80 > 132.9.25.130:2605': <PacketList: TCP:3 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.68.49.213:25 > 173.190.198.112:3053': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 193.235.219.144:80 > 173.190.214.63:4895': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.118.216:25 > 146.162.51.125:30218': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 129.46.3.206:1382 > 220.44.134.88:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.25.130:2531 > 203.106.142.236:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.25.130:2420 > 203.106.142.236:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 9.38.174.174:81 > 132.9.25.133:2365': <PacketList: TCP:3 UDP:0 ICMP:0 Other:0>,
#  'TCP 129.46.170.232:2727 > 217.130.48.127:80': <PacketList: TCP:5 UDP:0 ICMP:0 Other:0>,
#  'TCP 222.164.196.203:8080 > 132.2.92.24:1971': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.22.29:25 > 221.215.163.229:1262': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.234.9:25 > 215.196.48.8:45268': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'ICMP 173.190.214.95 > 209.13.145.149 type=8 code=0 id=0x100': <PacketList: TCP:0 UDP:0 ICMP:1 Other:0>,
#  'TCP 173.190.218.131:3322 > 129.128.94.132:25': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.218.131:4785 > 193.235.92.146:25': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 130.210.135.237:80 > 132.47.216.193:3903': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'UDP 171.37.25.91:3058 > 193.146.53.202:53': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'UDP 214.50.42.44:50535 > 208.15.71.64:4000': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 193.2.25.132:80 > 132.47.192.71:2636': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.165.198.240:3312 > 173.190.232.85:21': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 192.154.170.2:6663 > 173.190.193.1:62946': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 193.2.29.66:80 > 132.47.192.71:2766': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 203.106.142.236:80 > 132.9.25.130:2565': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 171.37.103.156:53 > 216.99.88.147:53': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 203.106.142.236:80 > 132.47.134.53:61004': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 129.46.165.223:1578 > 59.36.81.47:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 21.184.161.43:25 > 134.50.232.246:4036': <PacketList: TCP:7 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.149:4794 > 214.170.80.226:25': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.148:2022 > 214.179.15.13:25': <PacketList: TCP:4 UDP:0 ICMP:0 Other:0>,
#  'UDP 214.200.3.161:53 > 211.21.188.175:53': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 129.46.12.19:3247 > 203.106.142.236:80': <PacketList: TCP:3 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.50.42.44:50605 > 211.210.13.178:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 214.50.42.44:50516 > 208.15.68.67:4000': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'UDP 215.46.68.32:53 > 222.10.167.200:1832': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 193.235.239.202:80 > 221.133.178.46:2198': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 203.106.142.236:80 > 132.9.25.130:2519': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.199.61:1072 > 209.61.49.100:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 129.46.86.222:1125 > 203.113.53.77:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 193.2.35.1:43617 > 132.9.33.37:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 192.23.76.82:1551 > 221.133.178.44:6669': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 209.61.49.65:80 > 173.190.199.61:1075': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 216.179.46.254:53 > 132.47.128.123:53': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'UDP 221.50.98.125:53 > 129.47.67.140:53': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'UDP 129.213.115.194:7001 > 132.9.115.166:7003': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'UDP 214.50.42.44:50532 > 208.15.68.73:4000': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 193.194.142.138:2474 > 173.190.22.45:25': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.33.37:80 > 193.2.35.1:43617': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.25.130:2519 > 203.106.142.236:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.175.206.208:2684 > 193.68.97.38:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 193.235.219.150:80 > 132.21.33.89:1986': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 210.15.154.38:8888 > 173.190.216.16:1697': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 214.50.42.44:50567 > 208.15.71.73:4000': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 132.9.99.11:1422 > 210.60.107.64:80': <PacketList: TCP:4 UDP:0 ICMP:0 Other:0>,
#  'TCP 193.2.25.132:80 > 132.2.92.145:1818': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.198.112:3422 > 214.172.42.23:25': <PacketList: TCP:4 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.50.42.44:50526 > 193.225.133.106:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 129.46.86.222:1126 > 203.113.53.77:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.210.215:3773 > 210.8.90.23:7000': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.77.32:2849 > 209.61.52.144:3128': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 217.178.92.250:80 > 132.47.196.169:61375': <PacketList: TCP:3 UDP:0 ICMP:0 Other:0>,
#  'TCP 215.175.19.246:20 > 132.47.198.78:1191': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.148:2060 > 214.6.7.45:25': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 129.46.86.222:1127 > 203.113.53.76:80': <PacketList: TCP:5 UDP:0 ICMP:0 Other:0>,
#  'TCP 203.106.142.236:80 > 132.9.25.130:2459': <PacketList: TCP:3 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.166:47229 > 210.164.192.72:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.193.93:8000 > 222.21.97.188:1663': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 193.160.177.19:80 > 215.46.83.16:64354': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.148:1961 > 128.30.87.91:25': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 174.60.243.242:2652 > 173.190.21.86:25': <PacketList: TCP:3 UDP:0 ICMP:0 Other:0>,
#  'TCP 221.133.178.46:2198 > 193.235.239.202:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.25.130:2459 > 203.106.142.236:80': <PacketList: TCP:3 UDP:0 ICMP:0 Other:0>,
#  'TCP 129.46.21.60:1283 > 193.235.219.129:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 129.46.90.71:64949 > 203.106.142.236:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 193.84.221.118:80 > 132.9.25.169:3834': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.166:38246 > 193.235.219.146:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.190.40:4113 > 217.178.92.250:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 173.190.22.42:53 > 223.27.201.14:53': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 203.106.142.236:80 > 132.9.25.130:2604': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 129.46.177.26:1078 > 148.77.180.160:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 211.155.62.68:7000 > 173.190.76.133:1026': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'ICMP 129.46.101.17 > 171.189.177.235 type=3 code=3 id=None': <PacketList: TCP:0 UDP:0 ICMP:2 Other:0>,
#  'UDP 220.143.5.184:53 > 132.47.213.118:53': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 193.130.167.169:29232 > 132.2.136.47:25': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 217.72.251.124:4604 > 173.190.234.3:1822': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 217.72.251.124:4604 > 173.190.210.215:3710': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 129.46.21.60:1444 > 193.235.219.130:80': <PacketList: TCP:4 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.25.169:3834 > 193.84.221.118:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.25.130:2604 > 203.106.142.236:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 129.46.177.26:1077 > 148.77.162.168:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 129.46.101.17:28800 > 214.65.158.4:28800': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 214.200.3.148:2026 > 214.179.15.13:25': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 171.37.145.32:1043 > 193.2.25.132:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 133.103.186.172:80 > 132.9.229.24:1946': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 209.13.197.103:80 > 132.47.132.107:1144': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 203.106.142.236:80 > 132.2.200.72:2685': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'ICMP 215.77.35.133 > 132.47.134.53 type=0 code=0 id=0xfc02': <PacketList: TCP:0 UDP:0 ICMP:2 Other:0>,
#  'TCP 209.155.154.206:80 > 132.2.195.112:2396': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.211.18:80 > 208.42.145.88:1933': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 193.235.219.146:80 > 132.21.72.123:2480': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.25.130:2605 > 203.106.142.236:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.25.130:2565 > 203.106.142.236:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.22.42:27764 > 193.235.92.146:25': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 214.200.3.161:53 > 221.168.249.219:53': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 193.71.46.181:80 > 215.46.85.95:5061': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 214.200.3.161:53 > 211.184.253.180:53': <PacketList: TCP:0 UDP:2 ICMP:0 Other:0>,
#  'TCP 209.61.52.144:3128 > 173.190.77.32:2747': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 217.178.92.24:80 > 132.47.134.78:4287': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.210.219:2592 > 216.132.241.236:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.198.79:25 > 174.171.18.51:62466': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.153.114:25 > 221.215.163.229:3440': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 211.109.62.68:80 > 132.47.171.165:4368': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.209.10:2874 > 210.209.223.10:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.209.40:25 > 209.79.87.190:61438': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'UDP 208.15.68.87:4000 > 132.47.134.148:2913': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'ICMP 59.81.168.178 > 132.21.49.200 type=0 code=0 id=0x200': <PacketList: TCP:0 UDP:0 ICMP:2 Other:0>,
#  'ICMP 154.56.77.118 > 132.9.33.33 type=3 code=3 id=None': <PacketList: TCP:0 UDP:0 ICMP:1 Other:0>,
#  'TCP 214.162.25.81:25 > 173.190.76.132:4662': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 193.171.154.61:6667 > 173.190.215.9:4771': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 193.235.92.146:25 > 173.190.218.131:4785': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.214.63:5145 > 210.60.107.64:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'ICMP 173.190.214.60 > 209.13.145.149 type=8 code=0 id=0xfb6a': <PacketList: TCP:0 UDP:0 ICMP:1 Other:0>,
#  'TCP 173.190.199.61:1077 > 209.61.49.65:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 193.144.60.240:80 > 132.2.92.145:1801': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 215.46.68.0:31196 > 215.46.68.5:179': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 209.48.201.190:7000 > 173.190.77.61:64002': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 221.241.162.92:53 > 221.133.178.35:53': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'ICMP 209.13.145.149 > 173.190.214.95 type=0 code=0 id=0x100': <PacketList: TCP:0 UDP:0 ICMP:1 Other:0>,
#  'TCP 214.200.3.149:4876 > 214.165.185.38:25': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 209.61.49.100:80 > 173.190.199.61:1072': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 192.10.75.214:80 > 132.47.219.143:2474': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'UDP 130.141.130.229:53 > 129.46.165.26:53': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 211.229.244.41:80 > 132.47.192.27:2714': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 215.46.69.101:4251 > 193.146.53.202:53': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 173.190.232.85:80 > 214.172.149.28:2539': <PacketList: TCP:5 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.166:46942 > 211.51.72.111:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.193.100.241:1164 > 211.69.166.193:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.229.144:1821 > 193.235.219.128:80': <PacketList: TCP:3 UDP:0 ICMP:0 Other:0>,
#  'UDP 129.46.165.26:53 > 221.152.130.159:53': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 193.84.221.118:80 > 132.9.25.169:3816': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 215.175.19.246:21 > 132.47.198.78:1192': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 222.164.196.171:8080 > 132.2.92.24:1968': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.190.33:1147 > 203.113.220.40:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 215.46.64.251:80 > 209.234.88.222:65344': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 221.206.196.238:80 > 173.190.214.63:3513': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'UDP 208.15.71.76:4000 > 132.47.222.147:64024': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 173.190.232.85:80 > 214.172.149.28:11874': <PacketList: TCP:3 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.234.33:1237 > 211.130.28.255:6667': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 193.144.76.124:80 > 132.47.209.22:63564': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'ICMP 129.46.101.17 > 193.81.1.24 type=3 code=3 id=None': <PacketList: TCP:0 UDP:0 ICMP:2 Other:0>,
#  'TCP 203.106.142.236:80 > 132.47.220.4:2530': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.166:45607 > 211.160.205.58:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 217.178.92.250:80 > 132.47.134.78:4746': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 134.50.232.246:113 > 173.190.208.85:2897': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.221.45:4000 > 209.13.197.78:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.209.10:2877 > 193.54.210.172:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'UDP 214.200.3.145:1026 > 209.246.43.194:53': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'UDP 171.37.103.156:53 > 175.60.223.15:32860': <PacketList: TCP:0 UDP:249 ICMP:0 Other:0>,
#  'TCP 173.190.208.85:25 > 134.50.232.246:4100': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.198.66:62196 > 211.86.80.111:6668': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.217.86:25 > 214.172.42.17:1963': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.148:2013 > 214.179.15.13:25': <PacketList: TCP:4 UDP:0 ICMP:0 Other:0>,
#  'TCP 203.106.142.236:80 > 132.9.25.130:2589': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 168.161.18.71:2004 > 209.161.43.224:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.166:46829 > 209.222.238.106:80': <PacketList: TCP:6 UDP:0 ICMP:0 Other:0>,
#  'ICMP 129.46.97.248 > 193.2.29.66 type=8 code=0 id=0x200': <PacketList: TCP:0 UDP:0 ICMP:1 Other:0>,
#  'TCP 217.178.92.241:80 > 132.47.216.239:4220': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.25.130:2589 > 203.106.142.236:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.229.24:1946 > 133.103.186.172:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 193.2.92.163:80 > 132.2.94.242:2038': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 217.205.144.201:6667 > 173.190.118.216:4634': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 214.50.42.44:50884 > 208.15.68.78:4000': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 217.178.92.242:80 > 132.2.89.22:2080': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 211.109.62.68:80 > 132.47.213.116:1538': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.215.139:2279 > 59.96.152.25:1080': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.166:47322 > 214.165.165.72:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 214.200.3.145:1026 > 209.37.174.34:53': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 203.106.142.236:80 > 132.9.25.130:2574': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 129.46.170.232:2721 > 203.180.24.31:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 217.178.92.19:80 > 132.9.190.40:4096': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 171.37.114.14:25 > 209.237.22.91:3411': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.166:47334 > 193.235.219.130:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 134.170.92.139:80 > 215.46.70.217:34770': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.190.40:4096 > 217.178.92.19:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'ICMP 211.148.216.250 > 173.190.208.65 type=0 code=0 id=0xc045': <PacketList: TCP:0 UDP:0 ICMP:1 Other:0>,
#  'TCP 210.60.120.175:80 > 132.2.94.242:2053': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 221.144.180.192:80 > 173.190.211.18:3520': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 221.144.160.239:80 > 132.21.72.123:2440': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.98.214:3769 > 209.177.184.176:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 215.46.70.217:34770 > 134.170.92.139:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'ICMP 129.46.212.0 > 209.12.147.6 type=8 code=0 id=0x200': <PacketList: TCP:0 UDP:0 ICMP:1 Other:0>,
#  'TCP 173.190.214.63:5224 > 210.60.107.64:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.166:47337 > 162.115.75.93:80': <PacketList: TCP:3 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.20.5:22525 > 221.144.162.61:80': <PacketList: TCP:4 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.25.169:3816 > 193.84.221.118:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 211.96.21.239:80 > 132.21.131.93:1270': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.99.77:1136 > 193.144.60.14:8088': <PacketList: TCP:3 UDP:0 ICMP:0 Other:0>,
#  'TCP 209.61.52.144:3128 > 173.190.77.32:2849': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 145.19.117.64:53 > 173.190.199.60:3292': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 193.2.16.236:80 > 132.47.210.91:47972': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 210.97.250.120:80 > 173.190.209.10:2604': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 208.15.12.3:1627 > 132.9.33.37:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.210.215:3817 > 193.2.172.27:25': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 129.46.18.193:1442 > 211.53.104.153:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 132.9.33.37:80 > 208.15.12.3:1627': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 129.46.101.17:1247 > 211.210.36.42:28840': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.77.32:2842 > 209.61.52.144:3128': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 215.46.68.32:53 > 215.172.226.173:1182': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'UDP 194.21.17.46:53 > 215.46.68.32:53': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 173.190.77.61:62358 > 217.110.98.251:6667': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 217.178.92.250:80 > 132.47.134.78:4750': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 215.77.35.133:80 > 132.47.134.53:64632': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 193.235.92.146:25 > 173.190.22.42:27764': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 217.205.145.3:53 > 173.190.198.4:53': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 173.190.210.146:1252 > 203.69.57.253:20': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 173.190.77.37:3130 > 209.61.52.144:3130': <PacketList: TCP:0 UDP:3 ICMP:0 Other:0>,
#  'UDP 173.190.77.37:3130 > 221.50.98.97:3130': <PacketList: TCP:0 UDP:3 ICMP:0 Other:0>,
#  'TCP 210.60.107.64:80 > 173.190.214.63:5145': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 215.46.68.32:53 > 194.21.17.46:53': <PacketList: TCP:0 UDP:60 ICMP:0 Other:0>,
#  'TCP 173.190.211.18:80 > 208.42.145.88:1931': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.235.112:2116 > 214.179.15.45:111': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.216.96:25 > 193.2.172.20:31603': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.214.63:5207 > 210.60.107.64:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.216.101:25 > 145.18.236.142:2141': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.214.63:5213 > 193.235.219.151:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.148:2050 > 214.165.185.38:25': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 203.106.142.236:80 > 132.2.200.72:2699': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.145:4524 > 210.191.55.221:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 129.46.101.17:28800 > 211.228.113.42:28800': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 132.9.25.169:3858 > 193.2.29.72:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'ICMP 173.190.118.221 > 214.179.15.13 type=3 code=1 id=None': <PacketList: TCP:0 UDP:0 ICMP:4 Other:0>,
#  'TCP 217.178.92.24:80 > 132.21.72.189:1726': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 217.178.92.24:80 > 132.47.192.118:1728': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 217.178.92.24:80 > 132.21.72.189:1728': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 223.77.105.248:53 > 215.46.68.32:53': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 173.190.234.149:80 > 193.2.35.7:46490': <PacketList: TCP:3 UDP:0 ICMP:0 Other:0>,
#  'TCP 129.46.14.188:1710 > 217.178.92.240:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.148:1966 > 214.162.24.12:25': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 193.2.16.247:80 > 132.2.163.36:1414': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 129.46.16.139:1960 > 148.77.185.155:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.152.28:25 > 214.172.149.150:28639': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 129.46.39.133:32787 > 193.152.43.65:53': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'UDP 129.46.198.51:36143 > 193.156.234.229:53': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 193.40.214.124:80 > 132.9.43.150:1047': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.198.112:3416 > 211.3.23.225:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.76.54:25 > 210.67.70.84:60572': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 193.2.25.132:80 > 132.2.136.194:3064': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 220.143.5.189:80 > 132.47.213.118:2868': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 131.24.135.67:7001 > 132.9.115.166:7003': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 129.46.90.71:64936 > 203.106.142.236:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 171.37.89.97:80 > 193.2.35.25:47156': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'ICMP 215.46.69.102 > 171.37.103.156 type=11 code=0 id=None': <PacketList: TCP:0 UDP:0 ICMP:1 Other:0>,
#  'TCP 173.190.208.81:2354 > 209.14.28.189:25': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.148:2055 > 209.14.28.189:25': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 193.146.53.202:53 > 215.46.69.101:4251': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 129.46.3.206:1389 > 220.44.134.86:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'ICMP 173.190.215.139 > 209.13.145.149 type=8 code=0 id=0x100': <PacketList: TCP:0 UDP:0 ICMP:1 Other:0>,
#  'TCP 132.9.99.77:1126 > 193.144.60.240:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.166:47165 > 214.165.165.72:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 212.114.16.78:53 > 132.47.213.118:53': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 214.200.3.149:4759 > 214.170.80.226:25': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 193.235.219.128:80 > 132.47.135.24:1287': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 193.235.219.130:80 > 132.21.33.89:2001': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'UDP 129.46.101.17:28800 > 215.149.12.107:28800': <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  'TCP 203.106.142.236:80 > 132.2.200.72:2714': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 214.200.3.166:47279 > 222.99.14.81:80': <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.198.112:3053 > 214.68.49.213:25': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 173.190.216.44:1173 > 209.13.197.96:8002': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'TCP 129.46.69.210:1143 > 193.68.97.142:80': <PacketList: TCP:1 UDP:0 ICMP:0 Other:0>,
#  'ICMP 214.50.42.44 > 209.12.147.6 type=8 code=0 id=0x8662': <PacketList: TCP:0 UDP:0 ICMP:1 Other:0>}

# %%
# create a graph with password = 123
# not mentioning the URL will automatically connect to the localhost Neo4j database
neo4jGraph = Graph(password="123")

# %%
for number, packet in enumerate(packets.sessions()):
    # split the Packet object to extract the information we need from it
    pkt = packet.split()
    
    # check the first element of the list to see what type it is
    if "TCP" in pkt[0]:
        firstNode = Node("Host", name=pkt[1].split(":")[0])
        secondNode = Node("Host", name=pkt[3].split(":")[0])
        # check if it's IPv4 or IPv6
        # convert the IP object into a string, splitting it and reading the first element of the array
        if(str(capfile.packets[0].packet.payload).split()[0] == 'ipv4'):
            # create a relationshipt of type TCP - IPv4
            SENDtcp = Relationship.type("TCP - IPv4")
        else:
            # create a relationshipt of type TCP - IPv6
            SENDtcp = Relationship.type("TCP - IPv6")
        
        # connect the relationship between the two nodes created above (loading into the database)
        neo4jGraph.merge(SENDtcp(firstNode, secondNode), "Host", "name")
        
    # check the first element of the list to see what type it is
    elif "UDP" in pkt[0]:
        # the second element in the packet object list is the sender address
        firstNode = Node("Host", name=pkt[1].split(":")[0])
        
         # the fourth element in the packet object list is the sender address
        secondNode = Node("Host", name=pkt[3].split(":")[0])
        
        # convert the UDP packet object into a string, splitting it and reading the first element of the array
        SENDudp = Relationship.type("UDP")
        
        # connect the relationship between the two nodes created above (loading into the database)
        neo4jGraph.merge(SENDudp(firstNode, secondNode), "Host", "name")
        
        
    # check the first element of the list to see what type it is
    elif "ICMP" in pkt[0]:
        # the second element in the packet object list is the sender address
        firstNode = Node("Host", name=pkt[1].split(":")[0])
        # the fourth element in the packet object list is the sender address
        
        secondNode = Node("Host", name=pkt[3].split(":")[0])
        
        # convert the ICMP packet object into a string, splitting it and reading the first element of the array
        SENDicmp = Relationship.type("ICMP")
        
         # connect the relationship between the two nodes created above (loading into the database)
        neo4jGraph.merge(SENDicmp(firstNode, secondNode), "Host", "name")
        
    # check the first element of the list to see what type it is
    elif "ARP" in pkt[0]:
        # the second element in the packet object list is the sender address
        firstNode = Node("Host", name=pkt[1].split(":")[0])
        
        # the fourth element in the packet object list is the sender address
        secondNode = Node("Host", name=pkt[3].split(":")[0])
        
        # convert the ARP packet object into a string, splitting it and reading the first element of the array
        SENDarp = Relationship.type("ARP")
        
        # connect the relationship between the two nodes created above (loading into the database)
        neo4jGraph.merge(SENDarp(firstNode, secondNode), "Host", "name")
